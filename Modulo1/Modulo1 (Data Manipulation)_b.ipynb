# %% [markdown]
# # Application: energy consumption in Netherland (2009-2019)
#
# Three network administrators (Enexis, Liander and Stedin) provide energy (electricty and gas) to almost all Netherland. These companies provide information about:
#
# 1. **net_manager**: regional network manager code
# 2. **purchase_area**: code area where the energy is purchased
# 3. **street**: street name
# 4. **zipcode_from**: zip postal codes at the beginning of the street
# 5. **zipcode_to**: zip postal codes at the end of the street
# 6. **city**: city name
# 7. **num_connections**: Number of connections in the range of zip postal codes of the street
# 8. **delivery_perc**: % of the net energy consumption.
# 9. **perc_of_active_connections**: % of active connections in the zipcode range
# 10. **type_of_connection**: principal type of connection in the zipcode range. For electricity is # fuses x # ampères. For gas is G4, G6, G10, G16, G25
# 11. **type_conn_perc**: % of presence of the principal type of connection in the zipcode range
# 12. **annual_consume**: Annual energy consumption (Kwh for electricity, and m3 for gas)
# 13. **annual_consume_lowtarif_perc**: % of consumption during the low tarif time periods (from 10 p.m. to 7 a.m. and during weekends)
# 14. **smartmeter_perc**: % of smartmeters in the zipcode ranges
#
# The data (in .csv format) are available at https://www.kaggle.com/lucabasa/dutch-energy
#
# In the present application, we will work with the electrictiy data for 2019 (file called *enexis_electricity_01012019.csv*) to illustrate the standard data manipulation process in Python.

# %% [markdown]
# # Load the CSV files as data frames

# %%
from pandas import read_csv
data = read_csv('enexis_electricity_01012019.csv', sep = ',')

# %% [markdown]
# # Data visualization

# %%
data                # view the data
data.head(10)       # view the first 10 rows of data
data.tail(10)       # view the last  10 rows of data
#data = data.rename(index = lambda x: x + 1) # index from 1 to n
# Out:
#         net_manager purchase_area                street zipcode_from  \
# 124576  Enexis B.V.        ENEXIS             Molenhorn       9997PN
# 124577  Enexis B.V.        ENEXIS            Noorderweg       9997PP
# 124578  Enexis B.V.        ENEXIS          Domies Laand       9997PR
# 124579  Enexis B.V.        ENEXIS       Doodstilsterweg       9998NJ
# 124580  Enexis B.V.        ENEXIS          't-Lage eind       9998XA
# 124581  Enexis B.V.        ENEXIS  Jacob Tilbusscherweg       9998XB
# 124582  Enexis B.V.        ENEXIS           Jan Boerweg       9998XC
# 124583  Enexis B.V.        ENEXIS               Knolweg       9998XE
# 124584  Enexis B.V.        ENEXIS        Stitswerderweg       9999XH
# 124585  Enexis B.V.        ENEXIS                 Stiel       9999XK
#
#        zipcode_to       city  num_connections  delivery_perc  \
# 124576     9997PN  ZANDEWEER               18          66.67
# 124577     9997PP  ZANDEWEER               23          95.65
# 124578     9997VG  ZANDEWEER               14          71.43
# 124579     9998NZ  ROTTUM GN               24          75.00
# 124580     9998XA  ROTTUM GN               14          64.29
# 124581     9998XB  ROTTUM GN               21          76.19
# 124582     9998XD  ROTTUM GN               20          60.00
# 124583     9999XG  ROTTUM GN               13          23.08
# 124584     9999XJ  STITSWERD               16          56.25
# 124585     9999XL  STITSWERD               21          66.67
#
#         perc_of_active_connections  type_conn_perc type_of_connection  \
# 124576                         100           61.11               3x25
# 124577                         100           65.22               3x25
# 124578                         100           78.57               3x25
# 124579                         100           41.67               3x25
# 124580                         100           57.14               3x25
# 124581                         100           57.14               3x25
# 124582                         100           55.00               3x25
# 124583                         100           53.85               3x25
# 124584                         100           62.50               3x25
# 124585                         100           47.62               3x25
#
#         annual_consume  annual_consume_lowtarif_perc  smartmeter_perc
# 124576         2769.11                         29.24            27.78
# 124577         6780.57                         46.27            13.04
# 124578         3662.57                         46.96            50.00
# 124579        10271.17                         54.62            62.50
# 124580         3253.86                         39.92            78.57
# 124581         7034.57                         47.49            76.19
# 124582         2170.80                         41.79            55.00
# 124583        10193.92                         51.67           100.00
# 124584         6795.38                         39.54            68.75
# 124585         2580.71                         40.03            71.43

# %% [markdown]
# # Data characterization

# %%
type(data)          # object’s type
data.shape          # data dimension
len(data)           # length of data
data.shape[0]       # length of data (number of rows)
data.shape[1]       # number of variables (columns)
data.info()         # data information (very similar to data.dtypes)
data.describe()     # statistical summarize
data.columns        # colnames
data.columns.values 
data.index          # index names
data.index.values

data.net_manager.unique().tolist()             # list of unique values
data.purchase_area.unique().tolist()
data.type_of_connection.unique().tolist()
len(data.street.unique().tolist())             # number of unique values
len(data.city.unique().tolist())               
len(data.type_of_connection.unique().tolist())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124586 entries, 0 to 124585
# Data columns (total 14 columns):
# net_manager                     124586 non-null object
# purchase_area                   124586 non-null object
# street                          124586 non-null object
# zipcode_from                    124586 non-null object
# zipcode_to                      124586 non-null object
# city                            124586 non-null object
# num_connections                 124586 non-null int64
# delivery_perc                   124181 non-null float64
# perc_of_active_connections      124586 non-null int64
# type_conn_perc                  124586 non-null float64
# type_of_connection              124586 non-null object
# annual_consume                  124586 non-null float64
# annual_consume_lowtarif_perc    124586 non-null float64
# smartmeter_perc                 124586 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 13.3+ MB
# 10

# %% [markdown]
# # Saving Data frames

# %%
data.to_csv('example.csv')
data.to_csv('example1.txt', sep=',')
data.to_csv('example2.txt', sep=' ')
data.to_csv('example3.txt', sep='\t')

# %% [markdown]
# # Extracting (subsetting or filtering) data from a data frame

# %%
data[0:5]                                               # extract specific range of rows
data[0:6:2]                                             # slice of data from i to j with step k
data[0:5][['city','street','zipcode_from','zipcode_to','annual_consume']]   # extract specific range of rows for a list of variables
data[['smartmeter_perc']]                               # extract a column. Also data['smartmeter_perc']
data[['type_of_connection', 'type_conn_perc']]          # extract specific columns

# Filter by index label
data.loc[5:10, 'street':'city']                         # extract specific range of row labels for a range of variables
data.loc[[1, 13, 29], :]                                # extract specific row labels for all variables
data.loc[:, ['type_of_connection', 'type_conn_perc']]   # extract specific columns (variables) for all indexes
data.loc[4, 'annual_consume']                           # extract a specific cell (row label and variable)

# Filter by index position
data.iloc[5:10,0:6]                                     # extract specific range of row indexes for a range of variables (not using labels)
data.iloc[:,0:6]
data.iloc[5:10,:]
data.iloc[[1, 1000, 2900], [2, 5, 7, 11]]
data.head(5)
# Out:
#    net_manager purchase_area     street zipcode_from zipcode_to       city  \
# 0  Enexis B.V.        ENEXIS    Sasdijk       4251AA     4251AA  WERKENDAM
# 1  Enexis B.V.        ENEXIS    Sasdijk       4251AB     4251AB  WERKENDAM
# 2  Enexis B.V.        ENEXIS    Sasdijk       4251AC     4251AC  WERKENDAM
# 3  Enexis B.V.        ENEXIS    Sasdijk       4251AD     4251AD  WERKENDAM
# 4  Enexis B.V.        ENEXIS  Heuveltje       4251AE     4251AG  WERKENDAM
#
#    num_connections  delivery_perc  perc_of_active_connections  type_conn_perc  \
# 0               42         100.00                         100           50.00
# 1               17         100.00                         100           41.18
# 2               11          81.82                         100           63.64
# 3               28         100.00                         100           39.29
# 4               21          90.48                         100           42.86
#
#   type_of_connection  annual_consume  annual_consume_lowtarif_perc  \
# 0               3x25         5459.71                         28.82
# 1               1x25         4614.24                         34.24
# 2               1x25         2520.73                         34.31
# 3               3x25         4275.46                         38.34
# 4               1x25         4620.24                         60.18
#
#    smartmeter_perc
# 0            11.90
# 1            41.18
# 2            36.36
# 3            28.57
# 4            33.33

# %% [markdown]
# ## Filter by column value (conditions)

# %%
data[data['city'] == 'WERKENDAM']
data[data.city == 'WERKENDAM']
data.loc[(data.city == 'WERKENDAM')]
data.loc[(data['city'] == 'WERKENDAM')]
data.query('city == "WERKENDAM"')

#
data[(data.city == 'WERKENDAM') & (data.num_connections > 45)]
data.loc[(data.city == 'WERKENDAM') & (data.num_connections > 45)]
data.query('city == "WERKENDAM" & num_connections > 45')

#
data[(data.city == 'WERKENDAM') & (data.num_connections > 42) & (data.num_connections <= 69)]
data.loc[(data.city == 'WERKENDAM') & (data.num_connections > 42) & (data.num_connections <= 69)]
data.query('city == "WERKENDAM" & 42 < num_connections <= 69')
# Out:
#      net_manager purchase_area        street zipcode_from zipcode_to  \
# 46   Enexis B.V.        ENEXIS       Richter       4251DA     4251DA
# 47   Enexis B.V.        ENEXIS       Richter       4251DB     4251DB
# 48   Enexis B.V.        ENEXIS    Korte Gang       4251DC     4251DD
# 51   Enexis B.V.        ENEXIS  Binnengriend       4251DH     4251DH
# 57   Enexis B.V.        ENEXIS       Richter       4251DR     4251DR
# 77   Enexis B.V.        ENEXIS      De Erker       4251EZ     4251EZ
# 81   Enexis B.V.        ENEXIS    Wilgenlaan       4251GE     4251GE
# 147  Enexis B.V.        ENEXIS     Weerenweg       4251LB     4251LC
# 194  Enexis B.V.        ENEXIS  Raadhuislaan       4251VS     4251VS
# 225  Enexis B.V.        ENEXIS    Lange Wiep       4251XZ     4251ZA
#
#           city  num_connections  delivery_perc  perc_of_active_connections  \
# 46   WERKENDAM               43          93.02                         100
# 47   WERKENDAM               69          59.42                         100
# 48   WERKENDAM               51          96.08                         100
# 51   WERKENDAM               46          97.83                         100
# 57   WERKENDAM               43          86.05                         100
# 77   WERKENDAM               54         100.00                         100
# 81   WERKENDAM               64          92.19                         100
# 147  WERKENDAM               45         100.00                         100
# 194  WERKENDAM               59          96.61                         100
# 225  WERKENDAM               45          97.78                         100
#
#      type_conn_perc type_of_connection  annual_consume  \
# 46            69.77               1x35         4384.33
# 47            56.52               3x25         3477.13
# 48            39.22               1x25         3581.22
# 51            89.13               1x35         2183.00
# 57            46.51               3x25         3014.09
# 77            92.59               1x25         1941.26
# 81            45.31               1x35         3526.38
# 147           31.11               3x25        23182.93
# 194           52.54               1x35         2696.92
# 225           51.11               1x35         2834.11
#
#      annual_consume_lowtarif_perc  smartmeter_perc
# 46                          25.98             9.30
# 47                          36.65            50.72
# 48                          20.99            13.73
# 51                          24.18            10.87
# 57                          46.11            44.19
# 77                          16.81             5.56
# 81                          12.50            15.63
# 147                         31.95            28.89
# 194                         45.53            13.56
# 225                         21.29            20.00

# %% [markdown]
# ## Selecting random samples

# %%
data.sample(n=6, replace=False) # sampling a number of observations
data.sample(frac=0.001)         # sampling a fraction of observations
# Out:
#        net_manager purchase_area               street zipcode_from zipcode_to  \
# 23776  Enexis B.V.        ENEXIS           Neerstraat       5215AR     5215AR
# 72683  Enexis B.V.        ENEXIS         Dommelstraat       6413VX     6413VX
# 92386  Enexis B.V.        ENEXIS      van Bothnialaan       7742WE     7742WE
# 66786  Enexis B.V.        ENEXIS       Berceusestraat       6217EK     6217EK
# 52822  Enexis B.V.        ENEXIS             Beekveld       5864CK     5864CM
# ...            ...           ...                  ...          ...        ...
# 92377  Enexis B.V.        ENEXIS           Oranjewijk       7742VP     7742VP
# 69147  Enexis B.V.        ENEXIS          Irenestraat       6267AX     6267AX
# 7115   Enexis B.V.        ENEXIS          Blaaksedijk       4793RN     4793RN
# 51309  Enexis B.V.        ENEXIS          Kogeldistel       5803HM     5803HM
# 15460  Enexis B.V.        ENEXIS  Jozef Israelsstraat       5025NT     5025NT
#
#                    city  num_connections  delivery_perc  \
# 23776  'S-HERTOGENBOSCH               22         100.00
# 72683           HEERLEN               10         100.00
# 92386         COEVORDEN               19          78.95
# 66786        MAASTRICHT               20          95.00
# 52822            MEERLO               11         100.00
# ...                 ...              ...            ...
# 92377         COEVORDEN               14           7.14
# 69147    CADIER EN KEER               11          81.82
# 7115           FIJNAART               18          83.33
# 51309            VENRAY               23          78.26
# 15460           TILBURG               17          88.24
#
#        perc_of_active_connections  type_conn_perc type_of_connection  \
# 23776                         100           81.82               1x35
# 72683                         100           60.00               1x35
# 92386                         100           52.63               1x35
# 66786                         100           60.00               1x25
# 52822                         100           72.73               3x25
# ...                           ...             ...                ...
# 92377                         100          100.00               1x35
# 69147                         100           72.73               1x25
# 7115                          100           55.56               3x25
# 51309                         100           91.30               1x35
# 15460                         100          100.00               1x35
#
#        annual_consume  annual_consume_lowtarif_perc  smartmeter_perc
# 23776         3119.27                         48.35            77.27
# 72683         3729.70                         43.74            10.00
# 92386         3200.05                         46.34           100.00
# 66786         3773.50                         50.22            75.00
# 52822         5421.18                         53.39            18.18
# ...               ...                           ...              ...
# 92377         1581.14                         47.20           100.00
# 69147         2865.18                         30.78            18.18
# 7115         13366.44                         53.74            77.78
# 51309         3183.96                         53.04            39.13
# 15460         2665.94                         52.32            88.24
#
# [125 rows x 14 columns]

# %% [markdown]
# # Concatenation

# %%
# Refer for details to https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
import pandas as pd

data_2018 = pd.read_csv('enexis_electricity_01012018.csv', sep = ',')
data_2019 = pd.read_csv('enexis_electricity_01012019.csv', sep = ',')

data_2018.shape      # (124163, 14)
data_2019.shape      # (124586, 14)

D1 = pd.concat([data_2018, data_2019], axis=0, ignore_index=True) # concatenate DataFrames along rows
D1.shape             # (248749, 14)

# Add a "year" columns to the datasets
newdata_2018 = data_2018.assign(year = 2018)
newdata_2018.shape   # (124163, 15)
newdata_2018.head(5)

newdata_2019 = data_2019.assign(year = 2019)
newdata_2019.shape   # (124586, 15)
newdata_2019.head(5)

D2 = pd.concat([newdata_2018, newdata_2019], axis=0, ignore_index=True)
D2.shape             # (248749, 15)
D2
# Out:
#         net_manager purchase_area                street zipcode_from  \
# 0       Enexis B.V.        ENEXIS               Sasdijk       4251AA
# 1       Enexis B.V.        ENEXIS               Sasdijk       4251AB
# 2       Enexis B.V.        ENEXIS               Sasdijk       4251AC
# 3       Enexis B.V.        ENEXIS               Sasdijk       4251AD
# 4       Enexis B.V.        ENEXIS             Heuveltje       4251AE
# ...             ...           ...                   ...          ...
# 248744  Enexis B.V.        ENEXIS  Jacob Tilbusscherweg       9998XB
# 248745  Enexis B.V.        ENEXIS           Jan Boerweg       9998XC
# 248746  Enexis B.V.        ENEXIS               Knolweg       9998XE
# 248747  Enexis B.V.        ENEXIS        Stitswerderweg       9999XH
# 248748  Enexis B.V.        ENEXIS                 Stiel       9999XK
#
#        zipcode_to       city  num_connections  delivery_perc  \
# 0          4251AA  WERKENDAM               42         100.00
# 1          4251AB  WERKENDAM               17         100.00
# 2          4251AC  WERKENDAM               11          81.82
# 3          4251AD  WERKENDAM               29         100.00
# 4          4251AG  WERKENDAM               21          90.48
# ...           ...        ...              ...            ...
# 248744     9998XB  ROTTUM GN               21          76.19
# 248745     9998XD  ROTTUM GN               20          60.00
# 248746     9999XG  ROTTUM GN               13          23.08
# 248747     9999XJ  STITSWERD               16          56.25
# 248748     9999XL  STITSWERD               21          66.67
#
#         perc_of_active_connections  type_conn_perc type_of_connection  \
# 0                              100           50.00               3x25
# 1                              100           41.18               1x25
# 2                              100           63.64               1x25
# 3                              100           41.38               3x25
# 4                              100           42.86               1x25
# ...                            ...             ...                ...
# 248744                         100           57.14               3x25
# 248745                         100           55.00               3x25
# 248746                         100           53.85               3x25
# 248747                         100           62.50               3x25
# 248748                         100           47.62               3x25
#
#         annual_consume  annual_consume_lowtarif_perc  smartmeter_perc  year
# 0              5860.21                         28.31             7.14  2018
# 1              4149.24                         28.33            29.41  2018
# 2              2389.27                         34.60            36.36  2018
# 3              3866.21                         32.11            17.24  2018
# 4              4416.52                         57.26            33.33  2018
# ...                ...                           ...              ...   ...
# 248744         7034.57                         47.49            76.19  2019
# 248745         2170.80                         41.79            55.00  2019
# 248746        10193.92                         51.67           100.00  2019
# 248747         6795.38                         39.54            68.75  2019
# 248748         2580.71                         40.03            71.43  2019
#
# [248749 rows x 15 columns]

# %% [markdown]
# # More about concatenation

# %%
D3 = pd.concat([newdata_2018, newdata_2019], axis=1)           # Concatenate columns (similar to cbind() in R)
D3.shape # (124586, 30)
D3

D4 = pd.concat([newdata_2018.reindex(newdata_2019.index), newdata_2019], axis=1) # Concatenate columns (similar to cbind() in R)
D4.shape # (124586, 30)
D4
# Out:
#         net_manager purchase_area     street zipcode_from zipcode_to  \
# 0       Enexis B.V.        ENEXIS    Sasdijk       4251AA     4251AA
# 1       Enexis B.V.        ENEXIS    Sasdijk       4251AB     4251AB
# 2       Enexis B.V.        ENEXIS    Sasdijk       4251AC     4251AC
# 3       Enexis B.V.        ENEXIS    Sasdijk       4251AD     4251AD
# 4       Enexis B.V.        ENEXIS  Heuveltje       4251AE     4251AG
# ...             ...           ...        ...          ...        ...
# 124581          NaN           NaN        NaN          NaN        NaN
# 124582          NaN           NaN        NaN          NaN        NaN
# 124583          NaN           NaN        NaN          NaN        NaN
# 124584          NaN           NaN        NaN          NaN        NaN
# 124585          NaN           NaN        NaN          NaN        NaN
#
#              city  num_connections  delivery_perc  perc_of_active_connections  \
# 0       WERKENDAM             42.0         100.00                       100.0
# 1       WERKENDAM             17.0         100.00                       100.0
# 2       WERKENDAM             11.0          81.82                       100.0
# 3       WERKENDAM             29.0         100.00                       100.0
# 4       WERKENDAM             21.0          90.48                       100.0
# ...           ...              ...            ...                         ...
# 124581        NaN              NaN            NaN                         NaN
# 124582        NaN              NaN            NaN                         NaN
# 124583        NaN              NaN            NaN                         NaN
# 124584        NaN              NaN            NaN                         NaN
# 124585        NaN              NaN            NaN                         NaN
#
#         type_conn_perc  ...       city  num_connections  delivery_perc  \
# 0                50.00  ...  WERKENDAM               42         100.00
# 1                41.18  ...  WERKENDAM               17         100.00
# 2                63.64  ...  WERKENDAM               11          81.82
# 3                41.38  ...  WERKENDAM               28         100.00
# 4                42.86  ...  WERKENDAM               21          90.48
# ...                ...  ...        ...              ...            ...
# 124581             NaN  ...  ROTTUM GN               21          76.19
# 124582             NaN  ...  ROTTUM GN               20          60.00
# 124583             NaN  ...  ROTTUM GN               13          23.08
# 124584             NaN  ...  STITSWERD               16          56.25
# 124585             NaN  ...  STITSWERD               21          66.67
#
#         perc_of_active_connections  type_conn_perc type_of_connection  \
# 0                              100           50.00               3x25
# 1                              100           41.18               1x25
# 2                              100           63.64               1x25
# 3                              100           39.29               3x25
# 4                              100           42.86               1x25
# ...                            ...             ...                ...
# 124581                         100           57.14               3x25
# 124582                         100           55.00               3x25
# 124583                         100           53.85               3x25
# 124584                         100           62.50               3x25
# 124585                         100           47.62               3x25
#
#        annual_consume annual_consume_lowtarif_perc smartmeter_perc  year
# 0             5459.71                        28.82           11.90  2019
# 1             4614.24                        34.24           41.18  2019
# 2             2520.73                        34.31           36.36  2019
# 3             4275.46                        38.34           28.57  2019
# 4             4620.24                        60.18           33.33  2019
# ...               ...                          ...             ...   ...
# 124581        7034.57                        47.49           76.19  2019
# 124582        2170.80                        41.79           55.00  2019
# 124583       10193.92                        51.67          100.00  2019
# 124584        6795.38                        39.54           68.75  2019
# 124585        2580.71                        40.03           71.43  2019
#
# [124586 rows x 30 columns]

# %% [markdown]
# ## Remove (columns and rows) and rename column names and row indexes
# Note that **net_manager** and **purchase_area** are practically the same, so we eliminate the **net_manager**, and rename the **purchase_area** by **manager**. Additionally, **perc_of_active_connections** is constant, so we eliminate this variable.
#
# Also, we rename some variables for short names: **zipcode_from** by **zip_from**, **zipcode_to** by **zip_to**, **num_connections** by **connection**, **delivery_perc** by **delivery_%**, **type_conn_perc** by **type_conn_%**, **type_of_connection** by **type_connection**, **annual_consume** by **consumption**,
# **annual_consume_lowtarif_perc** by **consumption_lowtarif_%**, and **smartmeter_perc** by **smartmeter_%**.

# %%
import pandas as pd

data = pd.read_csv('enexis_electricity_01012019.csv', sep = ',')

data_new = data.drop(columns=['net_manager', 'perc_of_active_connections']) # also data.drop(['net_manager', 'perc_of_active_connections'], axis=1)
data_new
data_new.rename(columns={'purchase_area': 'manager',
                         'zipcode_from': 'zip_from',
                         'zipcode_to': 'zip_to',
                         'num_connections': 'connections',
                         'delivery_perc': 'delivery_%',
                         'type_conn_perc': 'type_conn_%',
                         'type_of_connection': 'type_connection',
                         'annual_consume': 'consumption',
                         'annual_consume_lowtarif_perc': 'consumption_lowtarif_%',
                         'smartmeter_perc': 'smartmeter_%'}
                , inplace=True)
data_new.head(10)
#print(data_new.columns)
# Out:
#   manager           street zip_from  zip_to       city  connections  \
# 0  ENEXIS          Sasdijk   4251AA  4251AA  WERKENDAM           42
# 1  ENEXIS          Sasdijk   4251AB  4251AB  WERKENDAM           17
# 2  ENEXIS          Sasdijk   4251AC  4251AC  WERKENDAM           11
# 3  ENEXIS          Sasdijk   4251AD  4251AD  WERKENDAM           28
# 4  ENEXIS        Heuveltje   4251AE  4251AG  WERKENDAM           21
# 5  ENEXIS        Koppenhof   4251AH  4251AH  WERKENDAM           13
# 6  ENEXIS            Plein   4251AJ  4251AJ  WERKENDAM           26
# 7  ENEXIS      Zevenhuizen   4251AK  4251AL  WERKENDAM           11
# 8  ENEXIS      Krommesteeg   4251AM  4251AN  WERKENDAM           14
# 9  ENEXIS  Van Brakelsteeg   4251AP  4251AR  WERKENDAM           12
#
#    delivery_%  type_conn_% type_connection  consumption  \
# 0      100.00        50.00            3x25      5459.71
# 1      100.00        41.18            1x25      4614.24
# 2       81.82        63.64            1x25      2520.73
# 3      100.00        39.29            3x25      4275.46
# 4       90.48        42.86            1x25      4620.24
# 5      100.00        38.46            1x25      3037.38
# 6      100.00        38.46            1x25      5317.81
# 7      100.00        54.55            3x25      2473.82
# 8      100.00        50.00            1x25      2962.21
# 9      100.00        50.00            1x25      2035.58
#
#    consumption_lowtarif_%  smartmeter_%
# 0                   28.82         11.90
# 1                   34.24         41.18
# 2                   34.31         36.36
# 3                   38.34         28.57
# 4                   60.18         33.33
# 5                   40.24         38.46
# 6                   32.82         23.08
# 7                   44.87         18.18
# 8                   25.46         21.43
# 9                   30.54         16.67

# %% [markdown]
# # Sort Data Frames

# %%
data_new.sort_values(by=['consumption'], ascending=True, na_position='first')
#data_new.sort_values(by=['consumption', 'delivery_%'], ascending=True, na_position='last')
# Out:
#        manager             street zip_from  zip_to            city  \
# 123268  ENEXIS           Vlamoven   9934ND  9934ND        DELFZIJL
# 93858   ENEXIS       Helmbloemwal   7813CJ  7813CJ           EMMEN
# 105952  ENEXIS  Langeloerduinen 4   9331WT  9331WT            NORG
# 1639    ENEXIS           Bommesee   4614XT  4614XT  BERGEN OP ZOOM
# 123876  ENEXIS       Oosterlaagte   9965SH  9965SH           LEENS
# ...        ...                ...      ...     ...             ...
# 32856   ENEXIS           Het Goor   5427PH  5427PH          BOEKEL
# 76869   ENEXIS              Brink   7411BS  7411BS        DEVENTER
# 13313   ENEXIS      Plukmadeseweg   4921AW  4921AW            MADE
# 50191   ENEXIS         Lupinenweg   5753SC  5753SC          DEURNE
# 42474   ENEXIS                Esp   5633AD  5633AE       EINDHOVEN
#
#         connections  delivery_%  type_conn_% type_connection  consumption  \
# 123268           13      100.00        92.31            1x35        60.92
# 93858            16      100.00        93.75            1x40       165.44
# 105952           35      100.00        97.14            1x40       468.63
# 1639             44      100.00        97.73            1x25       472.27
# 123876           15      100.00       100.00            1x40       600.20
# ...             ...         ...          ...             ...          ...
# 32856            14       92.86        28.57            3x80     58223.14
# 76869            11       81.82        27.27            1x35     58555.00
# 13313            11       90.91        36.36            3x63     58623.91
# 50191            10      100.00        50.00            3x25     63938.40
# 42474            11       81.82        54.55            3x63     66823.00
#
#         consumption_lowtarif_%  smartmeter_%
# 123268                    2.90         38.46
# 93858                    51.87        100.00
# 105952                    7.95          8.57
# 1639                     57.97        100.00
# 123876                   45.48        100.00
# ...                        ...           ...
# 32856                    42.81         42.86
# 76869                    40.89         72.73
# 13313                    55.63         63.64
# 50191                    50.94         50.00
# 42474                    43.40        100.00
#
# [124586 rows x 12 columns]

# %% [markdown]
# # Group dataframes by variables and functions of variables
# See https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html

# %%
D2.groupby(['year'])['annual_consume'].mean()            # group by year the mean consumption
D2.groupby(['year'])['num_connections'].sum()            # group by year the sum of connections
D2.groupby(['year'])['smartmeter_perc'].mean()           # group by year the mean of the % of smartmeters

data_new.groupby(['city'])['consumption'].mean()         # group by cities according to the mean consumption
data_new.groupby(['city']).agg({'consumption': 'mean'})  # also
data_new.groupby(['city']).agg({'consumption': 'sum'})   # group by cities according to the aggregated consumption
data_new.groupby(['city'])['consumption'].sum()          # also group by cities according to the mean consumption
data_new.groupby(['city'])['consumption'].std()          # group by cities according to the standard deviation of the consumption
# Out:
# city
# 'S GRAVENMOER       2298.802536
# 'S-HEERENBROEK      3418.770208
# 'S-HERTOGENBOSCH    4204.236138
# 'T HAANTJE           535.774809
# 'T WAAR              540.532019
#                        ...
# ZWARTSLUIS          2918.914377
# ZWEELOO             3660.823927
# ZWIGGELTE           9563.477779
# ZWINDEREN           4940.259459
# ZWOLLE              3597.522112
# Name: consumption, Length: 1066, dtype: float64
