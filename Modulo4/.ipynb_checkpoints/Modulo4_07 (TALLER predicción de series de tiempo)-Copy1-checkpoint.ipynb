# %% [markdown]
# ## Application: Colombian electricity spot price

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/jdariasl/DiplomadoEPM_2019/master/Modulo4/init.py
from init import init; init(force_download=False)

# %%
import sys
if 'google.colab' in sys.modules:
    print ("setting tensorflow version in colab")
    # %tensorflow_version 2.x
    # %load_ext tensorboard
import tensorflow as tf
tf.__version__

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
# %matplotlib inline

data_set = pd.read_csv('local/data/price.csv', sep = '\t', squeeze = True)
Prices = data_set.values
date_begin = np.datetime64('2000-01-01T00:00:00')
date_end = np.datetime64('2019-01-01T00:00:00')
Time = np.arange(date_begin,date_end,dtype='datetime64[h]')

plt.plot(Time,Prices)
plt.title("Hourly spot electricity price")
plt.ylabel('COL/kWh')
plt.show()

# %%
from pandas import Series
from statsmodels.graphics.tsaplots import plot_acf
k=72
series = Series(Prices)
plot_acf(series, lags=k)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(series, lags=k)
plt.show()

# %%
df = pd.DataFrame({'prices':Prices,'dates':Time})
#df['dates'] = pd.DatetimeIndex(df['dates'],freq ='H')
df['dates'] = pd.to_datetime(df['dates'])
df['just_date'] = df['dates'].dt.date
df['day_of_week'] = df['dates'].dt.weekday_name
df['month'] = df['dates'].dt.strftime('%b')
df['Year'] = df['dates'].dt.year
print(df[:100:25])
# Out:
#     prices               dates   just_date day_of_week month  Year
# 0    46.28 2000-01-01 00:00:00  2000-01-01    Saturday   Jan  2000
# 25   32.28 2000-01-02 01:00:00  2000-01-02      Sunday   Jan  2000
# 50   32.28 2000-01-03 02:00:00  2000-01-03      Monday   Jan  2000
# 75   32.28 2000-01-04 03:00:00  2000-01-04     Tuesday   Jan  2000

# %% [markdown]
# Obtengo los índices del último mes que se usará para realizar las pruebas de validación

# %%
LastMont = df['month'][-1:].values
LastYear = df['Year'][-1:].values
df2 = df.loc[(df['month'] == LastMont[0]) & (df['Year'] == LastYear[0])]
IndLastMonth = df2.index[0]
print(df2[:100:25])
# Out:
#         prices               dates   just_date day_of_week month  Year
# 165816   80.10 2018-12-01 00:00:00  2018-12-01    Saturday   Dec  2018
# 165841   84.77 2018-12-02 01:00:00  2018-12-02      Sunday   Dec  2018
# 165866   76.30 2018-12-03 02:00:00  2018-12-03      Monday   Dec  2018
# 165891   91.97 2018-12-04 03:00:00  2018-12-04     Tuesday   Dec  2018

# %% [markdown]
# Como ya se explicó en sesiones anteriores filtramos por día:

# %%
import local.lib.EnergyPricesLibrary as Ep
look_back = 1
Days = np.array(['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
fig, axs = plt.subplots(4, 2, sharex='all')
fig.set_size_inches(20,20)
k1 = 0
k2 = 0
for j,d in enumerate(Days,0):
    trainX, trainY, testX, testY, scaler, df2, dataset = Ep.SplitTimeseries(df,'prices',day = d, ValData = 'index', TimeAhead = IndLastMonth, look_back = look_back)
    testY = scaler.inverse_transform(testY.reshape(len(testY),1))
    Nt = len(testY)
    k1 = j
    if j > 3:
        k1 = j-4
        k2 = 1
    for i in range(int(Nt/24)):
        Time3 = df2['just_date'][i*24:(i+1)*24].values
        axs[k1,k2].plot(testY[i*24:(i+1)*24,0],label=Time3[1])
        axs[k1,k2].set_title(d)
        axs[k1,k2].legend()
        axs[k1,k2].set_ylabel('COL/kWh')

# %%
day = 'Monday'
df2 = df.loc[df['day_of_week'] == day]
plt.plot(df2['dates'],df2['prices'])
plt.title(day)
plt.ylabel('COL/kWh')
plt.show()

# %% [markdown]
# Las mismas transformaciones vistas en las sesiones anteriores pueden ser aplicadas en este caso, aunque la red neuronal es un modelo no lineal y no algunas de ellas pueden no ser necesarias.
#
# ## Diferenciación

# %%
df2.assign(diff=df2['prices'].diff(periods=1))
plot_acf(df2['diff'].dropna(), lags=k)
plt.show()

# %% [markdown]
# ## Box-Cox

# %%
from scipy import stats
fig = plt.figure()
ax1 = fig.add_subplot(211)
x = stats.loggamma.rvs(5, size=500) + 5
prob = stats.probplot(df2['prices'], dist=stats.norm, plot=ax1)
ax1.set_xlabel('')
ax1.set_title('Probplot against normal distribution')
ax2 = fig.add_subplot(212)
xt, lmbda = stats.boxcox(df2['prices'].values)
df2 = df2.assign(BoxCox = xt)
prob = stats.probplot(xt, dist=stats.norm, plot=ax2)
ax2.set_title('Probplot after Box-Cox transformation')
plt.show()

# %%
lmbda
# Out:
# -0.36761980982758474

# %%
xt
# Out:
# array([1.96182097, 1.96182097, 1.96182097, ..., 2.41500268, 2.39893903,
#        2.39893903])

# %% [markdown]
# ### Se debe tener en cuenta que en todos los casos se debe poder hacer la transformada inversa

# %%
from scipy.special import inv_boxcox
inv_boxcox(xt, lmbda)
# Out:
# array([ 32.28,  32.28,  32.28, ..., 383.92, 333.92, 333.92])

# %%
df2.prices.values
# Out:
# array([ 32.28,  32.28,  32.28, ..., 383.92, 333.92, 333.92])

# %% [markdown]
# Veamos la función de autocorrelación

# %%
series = Series(xt)
plot_acf(series, lags=k)
plt.show()

# %% [markdown]
#  ### Remove seasonality

# %%
df2['DesSeasonality'] = df2['BoxCox'].diff(periods=24)

# %%
plot_acf(df2['DesSeasonality'].dropna(), lags=k)
plt.show()

# %% [markdown]
# ### Differentiation

# %%
df2['Diff'] = df2['DesSeasonality'].diff(periods=1)
plot_acf(df2['Diff'].dropna(), lags=k)
plt.show()

# %% [markdown]
# # Predicción de un paso adelante

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error
from tensorflow.keras.callbacks import EarlyStopping
import math

# %%
dropout = 0
look_back = 1
# TimeAhead = 96
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseries(df,'prices',day = day, ValData = 'index', TimeAhead = IndLastMonth, look_back = look_back)
trainX=np.swapaxes(trainX,1,2)
# create and fit the GRU network
model = Sequential()
model.add(GRU(10, activation='relu',input_shape=(look_back,1),dropout=dropout,recurrent_dropout=dropout))
model.add(Dense(1))
Optimi = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=40, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
# Out:
# Train on 21318 samples, validate on 2369 samples
# Epoch 1/40
# 21318/21318 - 5s - loss: 0.0021 - mae: 0.0244 - val_loss: 1.2445e-04 - val_mae: 0.0094
# Epoch 2/40
# 21318/21318 - 6s - loss: 5.4024e-04 - mae: 0.0124 - val_loss: 4.1313e-05 - val_mae: 0.0045
# Epoch 3/40
# 21318/21318 - 7s - loss: 1.0535e-04 - mae: 0.0042 - val_loss: 4.1249e-05 - val_mae: 0.0043
# Epoch 4/40
# 21318/21318 - 4s - loss: 9.7245e-05 - mae: 0.0034 - val_loss: 3.2850e-05 - val_mae: 0.0024
# Epoch 5/40
# 21318/21318 - 6s - loss: 9.6620e-05 - mae: 0.0033 - val_loss: 3.8206e-05 - val_mae: 0.0038
# Epoch 6/40
# 21318/21318 - 4s - loss: 9.5919e-05 - mae: 0.0033 - val_loss: 3.3004e-05 - val_mae: 0.0024
# Epoch 7/40
# 21318/21318 - 7s - loss: 9.6096e-05 - mae: 0.0033 - val_loss: 3.2885e-05 - val_mae: 0.0024
# Epoch 8/40
# 21318/21318 - 5s - loss: 9.5577e-05 - mae: 0.0032 - val_loss: 3.3515e-05 - val_mae: 0.0026
# Epoch 9/40
# 21318/21318 - 6s - loss: 9.5079e-05 - mae: 0.0032 - val_loss: 3.6051e-05 - val_mae: 0.0034
# Epoch 10/40
# 21318/21318 - 6s - loss: 9.5312e-05 - mae: 0.0033 - val_loss: 3.5166e-05 - val_mae: 0.0031
# Epoch 11/40
# 21318/21318 - 6s - loss: 9.5626e-05 - mae: 0.0033 - val_loss: 3.3032e-05 - val_mae: 0.0024
# Epoch 12/40
# 21318/21318 - 6s - loss: 9.4456e-05 - mae: 0.0033 - val_loss: 3.3815e-05 - val_mae: 0.0027
# Epoch 13/40
# 21318/21318 - 6s - loss: 9.5217e-05 - mae: 0.0032 - val_loss: 3.3098e-05 - val_mae: 0.0025
# Epoch 14/40
# 21318/21318 - 6s - loss: 9.4698e-05 - mae: 0.0033 - val_loss: 3.3208e-05 - val_mae: 0.0023

# %%
# Plot training & validation metrics
plt.plot(model.history.history['mae'])
plt.plot(model.history.history['val_mae'])
plt.title('Model accuracy')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
testX=np.swapaxes(testX,1,2)
# make predictions
Predict = model.predict(np.concatenate((trainX,testX),axis=0))

# %%
# invert predictions
trainPredict = scaler.inverse_transform(Predict[:trainX.shape[0],:])
trainY = scaler.inverse_transform(trainY.reshape(len(trainY),1))
testPredict = scaler.inverse_transform(Predict[trainX.shape[0]:,:])
testY = scaler.inverse_transform(testY.reshape(len(testY),1))
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 26.09 RMSE
# Train Score: 0.07 MAPE
# Test Score: 19.22 RMSE
# Test Score: 0.05 MAPE

# %%
datasetO = scaler.inverse_transform(dataset)
Nt = trainPredict.shape[0] + testPredict.shape[0]+look_back
trainPredictPlot = np.zeros((Nt,1))
trainPredictPlot[:,:] = np.nan
trainPredictPlot[:len(trainPredict)+look_back, :] = np.concatenate((datasetO[:look_back].reshape(look_back,1),trainPredict))
# shift test predictions for plotting
testPredictPlot = np.zeros((Nt,1))
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+look_back:Nt, :] = testPredict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(dataset),label='Original data')
plt.plot(trainPredictPlot,label='Training predictions')
plt.plot(testPredictPlot,label='Test prediction')
plt.legend()
plt.show()

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()

# %% [markdown]
# ## Usando diferenciación

# %%
dropout = 0
look_back = 1
# TimeAhead = 96
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseries(df2,'diff',day = day, ValData = 'index', TimeAhead = IndLastMonth, look_back = look_back)
trainX=np.swapaxes(trainX,1,2)
# create and fit the GRU network
model = Sequential()
model.add(GRU(10, activation='relu',input_shape=(look_back,1),dropout=dropout,recurrent_dropout=dropout))
model.add(Dense(1))
Optimi = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=40, batch_size=20, verbose=0, validation_split=0.1,  callbacks=[stop])

# %%
# Plot training & validation metrics
plt.plot(model.history.history['mae'])
plt.plot(model.history.history['val_mae'])
plt.title('Model accuracy')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(model.history.history['loss'])
plt.plot(model.history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
testX=np.swapaxes(testX,1,2)
# make predictions
Predict = scaler.inverse_transform(model.predict(np.concatenate((trainX,testX),axis=0)))
Predict = Predict + df2['prices'][-Predict.shape[0]-1:-1].values.reshape(-1,1)
trainY = scaler.inverse_transform(trainY.reshape(-1,1)) + df2['prices'][look_back:trainX.shape[0]+look_back].values.reshape(-1,1)
testY = scaler.inverse_transform(testY.reshape(-1,1)) + df2['prices'][-testX.shape[0]-1:-1].values.reshape(-1,1)

# %%
# invert predictions
trainPredict = Predict[:trainX.shape[0],:]
trainY = trainY.reshape(len(trainY),1)
testPredict = Predict[trainX.shape[0]:,:]
testY = testY.reshape(len(testY),1)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 26.03 RMSE
# Train Score: 0.08 MAPE
# Test Score: 19.31 RMSE
# Test Score: 0.05 MAPE

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()

# %% [markdown]
# ### Usando la transformación Box-Cox

# %%
look_back = 1
dropout = 0
# TimeAhead = 96
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseries(df2,'BoxCox',day = day, ValData = 'index', TimeAhead = IndLastMonth, look_back = look_back)
trainX=np.swapaxes(trainX,1,2)
# create and fit the LSTM network
# create and fit the GRU network
model = Sequential()
model.add(GRU(10, activation='relu',input_shape=(look_back,1),dropout=dropout,recurrent_dropout=dropout))
model.add(Dense(1))
Optimi = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=20, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
# Out:
# Train on 21318 samples, validate on 2369 samples
# Epoch 1/20
# 21318/21318 - 4s - loss: 0.2210 - mae: 0.4246 - val_loss: 0.1070 - val_mae: 0.3161
# Epoch 2/20
# 21318/21318 - 2s - loss: 0.0496 - mae: 0.1793 - val_loss: 0.0098 - val_mae: 0.0783
# Epoch 3/20
# 21318/21318 - 3s - loss: 0.0173 - mae: 0.1056 - val_loss: 0.0045 - val_mae: 0.0596
# Epoch 4/20
# 21318/21318 - 3s - loss: 0.0148 - mae: 0.0979 - val_loss: 0.0038 - val_mae: 0.0547
# Epoch 5/20
# 21318/21318 - 4s - loss: 0.0118 - mae: 0.0871 - val_loss: 0.0029 - val_mae: 0.0472
# Epoch 6/20
# 21318/21318 - 4s - loss: 0.0083 - mae: 0.0722 - val_loss: 0.0021 - val_mae: 0.0383
# Epoch 7/20
# 21318/21318 - 3s - loss: 0.0051 - mae: 0.0552 - val_loss: 0.0014 - val_mae: 0.0288
# Epoch 8/20
# 21318/21318 - 3s - loss: 0.0030 - mae: 0.0390 - val_loss: 0.0011 - val_mae: 0.0207
# Epoch 9/20
# 21318/21318 - 3s - loss: 0.0021 - mae: 0.0271 - val_loss: 0.0011 - val_mae: 0.0164
# Epoch 10/20
# 21318/21318 - 4s - loss: 0.0018 - mae: 0.0213 - val_loss: 0.0011 - val_mae: 0.0152
# Epoch 11/20
# 21318/21318 - 5s - loss: 0.0018 - mae: 0.0198 - val_loss: 0.0011 - val_mae: 0.0155
# Epoch 12/20
# 21318/21318 - 5s - loss: 0.0018 - mae: 0.0196 - val_loss: 0.0011 - val_mae: 0.0159
# Epoch 13/20
# 21318/21318 - 5s - loss: 0.0018 - mae: 0.0192 - val_loss: 0.0011 - val_mae: 0.0139
# Epoch 14/20
# 21318/21318 - 5s - loss: 0.0018 - mae: 0.0190 - val_loss: 0.0011 - val_mae: 0.0152
# Epoch 15/20
# 21318/21318 - 5s - loss: 0.0018 - mae: 0.0189 - val_loss: 0.0011 - val_mae: 0.0144
# Epoch 16/20
# 21318/21318 - 4s - loss: 0.0018 - mae: 0.0189 - val_loss: 0.0011 - val_mae: 0.0146
# Epoch 17/20
# 21318/21318 - 3s - loss: 0.0018 - mae: 0.0188 - val_loss: 0.0011 - val_mae: 0.0145
# Epoch 18/20
# 21318/21318 - 4s - loss: 0.0018 - mae: 0.0188 - val_loss: 0.0011 - val_mae: 0.0141

# %%
testX=np.swapaxes(testX,1,2)
# make predictions
Predict = model.predict(np.concatenate((trainX,testX),axis=0))

# %%
# invert predictions
trainPredict = inv_boxcox(scaler.inverse_transform(Predict[:trainX.shape[0],:]), lmbda)
trainY = inv_boxcox(scaler.inverse_transform(trainY.reshape(len(trainY),1)), lmbda)
testPredict = inv_boxcox(scaler.inverse_transform(Predict[trainX.shape[0]:,:]), lmbda)
testY = inv_boxcox(scaler.inverse_transform(testY.reshape(len(testY),1)), lmbda)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 26.09 RMSE
# Train Score: 0.07 MAPE
# Test Score: 19.59 RMSE
# Test Score: 0.05 MAPE

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()

# %% [markdown]
# ### Removiendo la estacionalidad

# %%
look_back = 1
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseries(df2,'DesSeasonality',day = day, ValData = 'index', TimeAhead = IndLastMonth, look_back = look_back)
trainX=np.swapaxes(trainX,1,2)
# create and fit the LSTM network
model = Sequential()
model.add(GRU(10, activation='relu',input_shape=(look_back,1),dropout=dropout,recurrent_dropout=dropout))
model.add(Dense(1))
Optimi = Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=20, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
# Out:
# Train on 21296 samples, validate on 2367 samples
# Epoch 1/20
# 21296/21296 - 4s - loss: 0.1542 - mae: 0.3673 - val_loss: 0.0442 - val_mae: 0.2001
# Epoch 2/20
# 21296/21296 - 4s - loss: 0.0175 - mae: 0.1096 - val_loss: 0.0040 - val_mae: 0.0478
# Epoch 3/20
# 21296/21296 - 3s - loss: 0.0044 - mae: 0.0424 - val_loss: 0.0030 - val_mae: 0.0365
# Epoch 4/20
# 21296/21296 - 3s - loss: 0.0041 - mae: 0.0405 - val_loss: 0.0029 - val_mae: 0.0361
# Epoch 5/20
# 21296/21296 - 4s - loss: 0.0040 - mae: 0.0400 - val_loss: 0.0028 - val_mae: 0.0356
# Epoch 6/20
# 21296/21296 - 7s - loss: 0.0039 - mae: 0.0393 - val_loss: 0.0028 - val_mae: 0.0349
# Epoch 7/20
# 21296/21296 - 6s - loss: 0.0038 - mae: 0.0384 - val_loss: 0.0027 - val_mae: 0.0341
# Epoch 8/20
# 21296/21296 - 5s - loss: 0.0037 - mae: 0.0375 - val_loss: 0.0026 - val_mae: 0.0331
# Epoch 9/20
# 21296/21296 - 5s - loss: 0.0036 - mae: 0.0365 - val_loss: 0.0025 - val_mae: 0.0323
# Epoch 10/20
# 21296/21296 - 6s - loss: 0.0035 - mae: 0.0357 - val_loss: 0.0024 - val_mae: 0.0314
# Epoch 11/20
# 21296/21296 - 6s - loss: 0.0034 - mae: 0.0349 - val_loss: 0.0023 - val_mae: 0.0310
# Epoch 12/20
# 21296/21296 - 5s - loss: 0.0034 - mae: 0.0341 - val_loss: 0.0023 - val_mae: 0.0301
# Epoch 13/20
# 21296/21296 - 7s - loss: 0.0033 - mae: 0.0335 - val_loss: 0.0023 - val_mae: 0.0296
# Epoch 14/20
# 21296/21296 - 7s - loss: 0.0033 - mae: 0.0330 - val_loss: 0.0022 - val_mae: 0.0294
# Epoch 15/20
# 21296/21296 - 6s - loss: 0.0033 - mae: 0.0326 - val_loss: 0.0022 - val_mae: 0.0290
# Epoch 16/20
# 21296/21296 - 6s - loss: 0.0032 - mae: 0.0322 - val_loss: 0.0022 - val_mae: 0.0284
# Epoch 17/20
# 21296/21296 - 6s - loss: 0.0032 - mae: 0.0319 - val_loss: 0.0022 - val_mae: 0.0281
# Epoch 18/20
# 21296/21296 - 5s - loss: 0.0032 - mae: 0.0317 - val_loss: 0.0022 - val_mae: 0.0279
# Epoch 19/20
# 21296/21296 - 5s - loss: 0.0032 - mae: 0.0315 - val_loss: 0.0022 - val_mae: 0.0278
# Epoch 20/20
# 21296/21296 - 5s - loss: 0.0032 - mae: 0.0313 - val_loss: 0.0022 - val_mae: 0.0276

# %%
testX=np.swapaxes(testX,1,2)
# make predictions
Predict = scaler.inverse_transform(model.predict(np.concatenate((trainX,testX),axis=0)))
Predict = Predict + df2['BoxCox'][look_back:-24].values.reshape(-1,1)
trainY = scaler.inverse_transform(trainY.reshape(-1,1)) + df2['BoxCox'][look_back:trainX.shape[0]+look_back].values.reshape(-1,1)
testY = scaler.inverse_transform(testY.reshape(-1,1)) + df2['BoxCox'][-24-testX.shape[0]:-24].values.reshape(-1,1)

# %%
# invert predictions
trainPredict = inv_boxcox(Predict[:trainX.shape[0],:], lmbda)
trainY = inv_boxcox(trainY.reshape(len(trainY),1), lmbda)
testPredict = inv_boxcox(Predict[trainX.shape[0]:,:], lmbda)
testY = inv_boxcox(testY.reshape(len(testY),1), lmbda)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 40.26 RMSE
# Train Score: 0.11 MAPE
# Test Score: 27.73 RMSE
# Test Score: 0.09 MAPE

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()

# %% [markdown]
# ## Usando diferenciación despues de remover la componente estacional

# %%
look_back = 1
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseries(df2,'Diff',day = day, ValData = 'index', TimeAhead = IndLastMonth, look_back = look_back)
trainX=np.swapaxes(trainX,1,2)
# create and fit the LSTM network
model = Sequential()
model.add(GRU(10, activation='relu',input_shape=(look_back,1),dropout=dropout,recurrent_dropout=dropout))
model.add(Dense(1))
Optimi = Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=20, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
# Out:
# Train on 21295 samples, validate on 2367 samples
# Epoch 1/20
# 21295/21295 - 7s - loss: 0.0092 - mae: 0.0466 - val_loss: 0.0017 - val_mae: 0.0223
# Epoch 2/20
# 21295/21295 - 4s - loss: 0.0024 - mae: 0.0232 - val_loss: 0.0015 - val_mae: 0.0199
# Epoch 3/20
# 21295/21295 - 5s - loss: 0.0022 - mae: 0.0221 - val_loss: 0.0014 - val_mae: 0.0178
# Epoch 4/20
# 21295/21295 - 7s - loss: 0.0021 - mae: 0.0217 - val_loss: 0.0013 - val_mae: 0.0180
# Epoch 5/20
# 21295/21295 - 5s - loss: 0.0021 - mae: 0.0223 - val_loss: 0.0013 - val_mae: 0.0184
# Epoch 6/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0188
# Epoch 7/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0226 - val_loss: 0.0013 - val_mae: 0.0192
# Epoch 8/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0228 - val_loss: 0.0013 - val_mae: 0.0198
# Epoch 9/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0224 - val_loss: 0.0014 - val_mae: 0.0212
# Epoch 10/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0227 - val_loss: 0.0013 - val_mae: 0.0189
# Epoch 11/20
# 21295/21295 - 7s - loss: 0.0021 - mae: 0.0226 - val_loss: 0.0014 - val_mae: 0.0212
# Epoch 12/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0228 - val_loss: 0.0013 - val_mae: 0.0201
# Epoch 13/20
# 21295/21295 - 7s - loss: 0.0021 - mae: 0.0227 - val_loss: 0.0013 - val_mae: 0.0190
# Epoch 14/20
# 21295/21295 - 5s - loss: 0.0021 - mae: 0.0226 - val_loss: 0.0013 - val_mae: 0.0187
# Epoch 15/20
# 21295/21295 - 7s - loss: 0.0021 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0187
# Epoch 16/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0189
# Epoch 17/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0187
# Epoch 18/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0184
# Epoch 19/20
# 21295/21295 - 6s - loss: 0.0021 - mae: 0.0225 - val_loss: 0.0013 - val_mae: 0.0191
# Epoch 20/20
# 21295/21295 - 7s - loss: 0.0021 - mae: 0.0226 - val_loss: 0.0013 - val_mae: 0.0187

# %%
testX=np.swapaxes(testX,1,2)
# make predictions
Predict = scaler.inverse_transform(model.predict(np.concatenate((trainX,testX),axis=0)))
Predict = Predict + df2['DesSeasonality'][-Predict.shape[0]-1:-1].values.reshape(-1,1)
Predict = Predict + df2['BoxCox'][look_back+1:-24].values.reshape(-1,1)
trainY = scaler.inverse_transform(trainY.reshape(-1,1)) + df2['DesSeasonality'][24+look_back:trainX.shape[0]+look_back+24].values.reshape(-1,1)
trainY = trainY + df2['BoxCox'][look_back:trainX.shape[0]+look_back].values.reshape(-1,1)
testY = scaler.inverse_transform(testY.reshape(-1,1)) + df2['DesSeasonality'][-testX.shape[0]-1:-1].values.reshape(-1,1)
testY = testY + df2['BoxCox'][-24-testX.shape[0]:-24].values.reshape(-1,1)

# %%
# invert predictions
trainPredict = inv_boxcox(Predict[:trainX.shape[0],:], lmbda)
trainY = inv_boxcox(trainY.reshape(len(trainY),1), lmbda)
testPredict = inv_boxcox(Predict[trainX.shape[0]:,:], lmbda)
testY = inv_boxcox(testY.reshape(len(testY),1), lmbda)
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 390.91 RMSE
# Train Score: 0.16 MAPE
# Test Score: 25.56 RMSE
# Test Score: 0.07 MAPE

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()

# %% [markdown]
# ### Ejercicio
#
# Diseñar y entrenar una arquitectura que tome 5 días atrás y prediga las 24 horas del día siguiente usando un esquema Codificador Decodificador.

# %%
from tensorflow.keras.layers import Bidirectional
look_back = 48
n_steps_ahead = 24
dropout = 0
# TimeAhead = 96
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseriesMultipleTimesBackAheadRW(df,'prices',day = 'Monday', ValData = 'index', TimeAhead = IndLastMonth, n_steps_out=n_steps_ahead, n_steps_in = look_back)
#trainX=np.swapaxes(trainX,1,2)
# create and fit the GRU network
model = Sequential()
model.add(Bidirectional(GRU(10, activation = 'relu', input_shape=(look_back,1),dropout=dropout,recurrent_dropout=dropout)))
model.add(Dense(1))
Optimi = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=20, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
# Out:
# Train on 21276 samples, validate on 2364 samples
# Epoch 1/20
# 21276/21276 - 41s - loss: 4.3872e-04 - mae: 0.0074 - val_loss: 4.1782e-05 - val_mae: 0.0043
# Epoch 2/20
# 21276/21276 - 40s - loss: 1.1712e-04 - mae: 0.0047 - val_loss: 3.2936e-05 - val_mae: 0.0033
# Epoch 3/20
# 21276/21276 - 40s - loss: 1.0556e-04 - mae: 0.0045 - val_loss: 4.1269e-05 - val_mae: 0.0046
# Epoch 4/20
# 21276/21276 - 40s - loss: 1.0253e-04 - mae: 0.0044 - val_loss: 3.3275e-05 - val_mae: 0.0033
# Epoch 5/20
# 21276/21276 - 40s - loss: 9.8540e-05 - mae: 0.0042 - val_loss: 3.1703e-05 - val_mae: 0.0028
# Epoch 6/20
# 21276/21276 - 40s - loss: 9.8086e-05 - mae: 0.0042 - val_loss: 3.2126e-05 - val_mae: 0.0030
# Epoch 7/20
# 21276/21276 - 40s - loss: 9.6823e-05 - mae: 0.0041 - val_loss: 3.9987e-05 - val_mae: 0.0044
# Epoch 8/20
# 21276/21276 - 40s - loss: 9.6411e-05 - mae: 0.0041 - val_loss: 3.3966e-05 - val_mae: 0.0034
# Epoch 9/20
# 21276/21276 - 40s - loss: 9.4740e-05 - mae: 0.0040 - val_loss: 3.3700e-05 - val_mae: 0.0034
# Epoch 10/20
# 21276/21276 - 40s - loss: 9.3962e-05 - mae: 0.0039 - val_loss: 3.0945e-05 - val_mae: 0.0028
# Epoch 11/20
# 21276/21276 - 40s - loss: 9.4606e-05 - mae: 0.0039 - val_loss: 3.1520e-05 - val_mae: 0.0029
# Epoch 12/20
# 21276/21276 - 40s - loss: 9.3707e-05 - mae: 0.0039 - val_loss: 3.4973e-05 - val_mae: 0.0036
# Epoch 13/20
# 21276/21276 - 40s - loss: 9.2147e-05 - mae: 0.0037 - val_loss: 3.1957e-05 - val_mae: 0.0030
# Epoch 14/20
# 21276/21276 - 40s - loss: 9.2017e-05 - mae: 0.0038 - val_loss: 3.1796e-05 - val_mae: 0.0030
# Epoch 15/20
# 21276/21276 - 40s - loss: 9.1196e-05 - mae: 0.0037 - val_loss: 3.0829e-05 - val_mae: 0.0027
# Epoch 16/20
# 21276/21276 - 40s - loss: 9.2589e-05 - mae: 0.0038 - val_loss: 3.2584e-05 - val_mae: 0.0031
# Epoch 17/20
# 21276/21276 - 40s - loss: 9.1326e-05 - mae: 0.0038 - val_loss: 3.1298e-05 - val_mae: 0.0028
# Epoch 18/20
# 21276/21276 - 40s - loss: 9.0462e-05 - mae: 0.0037 - val_loss: 3.1850e-05 - val_mae: 0.0029
# Epoch 19/20
# 21276/21276 - 40s - loss: 9.0782e-05 - mae: 0.0038 - val_loss: 3.4568e-05 - val_mae: 0.0035
# Epoch 20/20
# 21276/21276 - 40s - loss: 9.0833e-05 - mae: 0.0037 - val_loss: 3.0901e-05 - val_mae: 0.0026

# %%
PredTest = []
Nd = testX.shape[0]
for i in range(Nd):
    xtemp = testX[i,:,:]
    for j in range(n_steps_ahead):
        pred = model.predict(xtemp.reshape(1,look_back,1))
        #pred = model.predict(xtemp.reshape(1,1,look_back))
        PredTest.append(pred)
        xtemp = np.r_[xtemp[1:,:],pred]

# %%
Predict = np.r_[model.predict(trainX),np.array(PredTest).reshape(len(PredTest),1)]
Predict.shape
# Out:
# (23760, 1)

# %%
# invert predictions
trainPredict = scaler.inverse_transform(Predict[:trainX.shape[0]].reshape(-1,1))
trainY = scaler.inverse_transform(trainY.reshape(len(trainY),1))
testPredict = scaler.inverse_transform(Predict[trainX.shape[0]:].reshape(-1,1))
testY = scaler.inverse_transform(testY.flatten().reshape(len(PredTest),1))
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 25.04 RMSE
# Train Score: 0.08 MAPE
# Test Score: 86.71 RMSE
# Test Score: 0.31 MAPE

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    #plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()

# %%
from tensorflow.keras.layers import TimeDistributed, RepeatVector
look_back = 24
overlap = 24
n_steps_ahead = 24
dropout = 0.2
# TimeAhead = 96
trainX, trainY, testX, testY, scaler, dfval, dataset = Ep.SplitTimeseriesMultipleTimesBackAhead(df2,'diff',day = 'Monday', ValData = 'index', TimeAhead = IndLastMonth, n_steps_out=n_steps_ahead, n_steps_in = look_back, overlap = overlap)
trainX=np.swapaxes(trainX,1,2)
# create and fit the GRU network
model = Sequential()
model.add(GRU(100, activation = 'relu', return_sequences=True, input_shape=(1,look_back),dropout=dropout,recurrent_dropout=dropout))
model.add(RepeatVector(n_steps_ahead))
model.add(GRU(100,activation = 'relu',return_sequences=True,dropout=dropout,recurrent_dropout=dropout))
model.add(TimeDistributed(Dense(1)))
Optimi = Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.999, amsgrad=False)
model.compile(loss='mean_squared_error', optimizer=Optimi, metrics=['mae'])
# Early stopping
stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
model.fit(trainX, trainY, epochs=100, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-6809534f6794> in <module>
#      15 # Early stopping
#      16 stop = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto', baseline=None, restore_best_weights=False)
# ---> 17 model.fit(trainX, trainY, epochs=100, batch_size=20, verbose=2, validation_split=0.1,  callbacks=[stop])
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     791         max_queue_size=max_queue_size,
#     792         workers=workers,
# --> 793         use_multiprocessing=use_multiprocessing)
#     794
#     795   def evaluate(self,
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     233           max_queue_size=max_queue_size,
#     234           workers=workers,
# --> 235           use_multiprocessing=use_multiprocessing)
#     236
#     237       total_samples = _get_total_number_of_samples(training_data_adapter)
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_v2.py in _process_training_inputs(model, x, y, batch_size, epochs, sample_weights, class_weights, steps_per_epoch, validation_split, validation_data, validation_steps, shuffle, distribution_strategy, max_queue_size, workers, use_multiprocessing)
#     550         batch_size=batch_size,
#     551         check_steps=False,
# --> 552         steps=steps_per_epoch)
#     553     (x, y, sample_weights,
#     554      val_x, val_y,
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2342         is_dataset=is_dataset,
#    2343         class_weight=class_weight,
# -> 2344         batch_size=batch_size)
#    2345
#    2346   def _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs,
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training.py in _standardize_tensors(self, x, y, sample_weight, run_eagerly, dict_inputs, is_dataset, class_weight, batch_size)
#    2448           # Additional checks to avoid users mistakenly using improper loss fns.
#    2449           training_utils.check_loss_and_target_compatibility(
# -> 2450               y, self._feed_loss_fns, feed_output_shapes)
#    2451
#    2452       sample_weights, _, _ = training_utils.handle_partial_sample_weights(
#
# ~/.local/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/training_utils.py in check_loss_and_target_compatibility(targets, loss_fns, output_shapes)
#     808           raise ValueError('A target array with shape ' + str(y.shape) +
#     809                            ' was passed for an output of shape ' + str(shape) +
# --> 810                            ' while using as loss `' + loss_name + '`. '
#     811                            'This loss expects targets to have the same shape '
#     812                            'as the output.')
#
# ValueError: A target array with shape (985, 24, 1) was passed for an output of shape (None, 1, 1) while using as loss `mean_squared_error`. This loss expects targets to have the same shape as the output.

# %%
testX=np.swapaxes(testX,1,2)
# make predictions
Predict = model.predict(np.concatenate((trainX,testX),axis=0))

# %%
plt.plot(Predict.flatten()[-5*24:])

# %%
plt.plot(trainX.flatten()[-500*24:-490*24])

# %%
Predict = Predict.flatten()
trainY = trainY.flatten()
testY = testY.flatten()

# %%
# invert predictions
trainPredict = scaler.inverse_transform(Predict[:trainX.shape[0]*n_steps_ahead].reshape(-1,1))
trainY = scaler.inverse_transform(trainY.reshape(len(trainY),1))
testPredict = scaler.inverse_transform(Predict[trainX.shape[0]*n_steps_ahead:].reshape(-1,1))
testY = scaler.inverse_transform(testY.reshape(len(testY),1))
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
print('Train Score: %.2f MAPE' % Ep.MAPE(trainPredict,trainY))
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
print('Test Score: %.2f MAPE' % Ep.MAPE(testPredict,testY))
# Out:
# Train Score: 60.82 RMSE
# Train Score: 0.25 MAPE
# Test Score: 64.11 RMSE
# Test Score: 0.23 MAPE

# %%
df3 = dfval.loc[(dfval['day_of_week'] == day) & (dfval.index >= IndLastMonth)]
Nt = len(df3)
plt.figure(figsize=(8,6))
for i in range(int(Nt/24)):
    Time3 = df3['just_date'][i*24:(i+1)*24].values
    plt.plot(testPredict[i*24:(i+1)*24,0],label=('Pred-'+ str(Time3[1])))
    #plt.plot(testY[i*24:(i+1)*24,0],linestyle='dashed',label=Time3[1])
    plt.title(day)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.ylabel('COL/kWh')
plt.show()
