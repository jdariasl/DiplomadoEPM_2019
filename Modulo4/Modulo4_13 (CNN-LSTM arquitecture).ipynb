# %% [markdown]
# # A CNN-LSTM architecture

# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/jdariasl/DiplomadoEPM_2019/master/Modulo4/init.py
from init import init; init(force_download=False)

# %%
import sys
if 'google.colab' in sys.modules:
    print ("setting tensorflow version in colab")
    # %tensorflow_version 2.x
    # %load_ext tensorboard
import tensorflow as tf
tf.__version__

# %% [markdown]
# This type of architecture is useful for different arquitectures, for instance, action recognition in video sequences. In order to show its use, we are going to create a syntethic dataset.

# %% [markdown]
# The dataset is composed of videos where a point moves through the frames forming four different patterns: a constant point, a point ascending from bottom-left corner to top-right corner, a point descending from top-lef corner to bottom-right corner, and a point following a sin function.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from keras.utils import np_utils
from tensorflow.keras.layers import LSTM, Conv2D, Dense, TimeDistributed, MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib notebook

# %%
import math
t = np.linspace(math.pi/10, 2*math.pi, num=20)
y = np.sin(t) + 0.05*np.random.randn(1, 20)
y = y.flatten()
i = 1
t2 = 6*i
y2 = int(np.round(23*(y[i-1]+1)+4))

# %%
def f(t2, y2):
    m = np.zeros((50,130))
    m[y2-3:y2+3,t2-3:t2+3] = 255
    return m

def updatefig(*args):
    global y,i
    if i == 20:
        i = 1
    t2 = 6*i
    y2 = int(np.round(23*(y[i-1]+1)+4))
    i += 1
    im.set_array(f(t2,y2))
    return im,

# %%
fig = plt.figure()
im = plt.imshow(f(t2, y2))
ani = animation.FuncAnimation(fig, updatefig, interval=50, frames=20, blit=True)
# Out:
# <img src="data:image/png;base64,..." width="712.4333333333333">

# %% [markdown]
# This is an example of a sin pattern.

# %%
from IPython.display import HTML
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge7a39101e975448581493360c407b193">
#   <div class="anim-controls">
#     <input id="_anim_slidere7a39101e975448581493360c407b193" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime7a39101e975448581493360c407b193.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anime7a39101e975448581493360c407b193.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anime7a39101e975448581493360c407b193.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anime7a39101e975448581493360c407b193.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selecte7a39101e975448581493360c407b193" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e7a39101e975448581493360c407b193"
#              >
#       <label for="_anim_radio1_e7a39101e975448581493360c407b193">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e7a39101e975448581493360c407b193"
#              checked>
#       <label for="_anim_radio2_e7a39101e975448581493360c407b193">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e7a39101e975448581493360c407b193"
#              >
#       <label for="_anim_radio3_e7a39101e975448581493360c407b193">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge7a39101e975448581493360c407b193";
#     var slider_id = "_anim_slidere7a39101e975448581493360c407b193";
#     var loop_select_id = "_anim_loop_selecte7a39101e975448581493360c407b193";
#     var frames = new Array(20);
#
#   frames[0] = "...\
# AAANxQAADcUBdMJIOwAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8li6FKAAAXl0lEQVR4nO3dfazWdf348dc5oCfgOnKOygQEExuQ\
# AXosWn8475L42Q0YSso0W5EsAdFs6h/ZAdnkj5ZsraFWOm+2nFqaZKMV4cy1akGbBzzenKlbiGSK\
# YufGw82B8/790bryxJdoM87VeZ3HY7vGzudznWuv673r4jz5fK7Poa6UUgIAILH6Wg8AAHC0CR4A\
# ID3BAwCkJ3gAgPQEDwCQnuABANITPABAeoIHAEhP8AAA6QkeACA9wQMApCd4AID0BA8AkJ7gAQDS\
# EzwAQHqCBwBIT/AAAOkJHgAgPcEDAKQneACA9AQPAJCe4AEA0hM8AEB6ggcASE/wAADpCR4AID3B\
# AwCkJ3gAgPQEDwCQnuABANITPABAeoIHAEhP8AAA6QkeACA9wQMApCd4AID0BA8AkJ7gAQDSEzwA\
# QHqCBwBIT/AAAOkJHgAgPcEDAK

# %% [markdown]
# The data must have the form **[n_samples,n_times,n_rows,n_columns,n_channels]**

# %%
#Class sin
Videos1 = np.zeros((20,20,50,130,1))
for j in range(20):
    y = np.sin(t) + 0.05*np.random.randn(1, 20)
    y = y.flatten()
    for i in range(20):
        t2 = 6*(i+1)
        y2 = int(np.round(23*(y[i]+1)+4))
        Videos1[j,i,:,:,0] = f(t2,y2)/255
#Class constan
Videos2 = np.zeros((20,20,50,130,1))
for j in range(20):
    for i in range(20):
        t2 = int(np.round(25 + np.random.randn(1)))
        y2 = int(np.round(65 + np.random.randn(1)))
        Videos2[j,i,:,:,0] = f(t2,y2)/255
#Class ascending
Videos3 = np.zeros((20,20,50,130,1))
for j in range(20):
    for i in range(20):
        t2 = 6*(i+1)
        y2 = int(np.round(2*(i+1) + 2 + np.random.randn(1)))
        Videos3[j,i,:,:,0] = f(t2,y2)/255
#Class descending
Videos4 = np.zeros((20,20,50,130,1))
for j in range(20):
    for i in range(20):
        t2 = 6*(i+1)
        y2 = int(np.round(2*(20-i)+ 2 + np.random.randn(1)))
        Videos4[j,i,:,:,0] = f(t2,y2)/255
Videos = np.concatenate((Videos1,Videos2,Videos3,Videos4),axis=0)

# %%
Videos.shape
# Out:
# (80, 20, 50, 130, 1)

# %%
Y = np.r_[np.zeros(20),np.ones(20),2*np.ones(20),3*np.ones(20)]
Y.shape
# Out:
# (80,)

# %%
# convert list of labels to binary class matrix
y_trainOHE = np_utils.to_categorical(Y)
nb_classes = y_trainOHE.shape[1]

# %%
nb_classes
# Out:
# 4

# %% [markdown]
# ### There are Three ways to define the network:
#
# 1)

# %%
# define CNN model
cnn = Sequential()
cnn.add(Conv2D(...))
cnn.add(MaxPooling2D(...))
cnn.add(Flatten())
# define LSTM model
model = Sequential()
model.add(TimeDistributed(cnn, ...))
model.add(LSTM(..))
model.add(Dense(...))

# %% [markdown]
# 2)

# %%
model = Sequential()
# define CNN model
model.add(TimeDistributed(Conv2D(...))
model.add(TimeDistributed(MaxPooling2D(...)))
model.add(TimeDistributed(Flatten()))
# define LSTM model
model.add(LSTM(...))
model.add(Dense(...))

# %% [markdown]
# Let's define our architecture:

# %%
rows = 50
columns = 130
channels = 1

model1 = Sequential()
model1.add(TimeDistributed(Conv2D(filters=5, kernel_size=(4, 4), 
                                 activation='relu', 
                                 padding='same', 
                                 input_shape=(rows, columns, channels))))
model1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model1.add(TimeDistributed(Conv2D(filters=5, kernel_size=(8, 8), 
                                 activation='relu', 
                                 padding='same', 
                                 input_shape=(rows, columns, channels))))
model1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model1.add(TimeDistributed(Conv2D(filters=5, kernel_size=(8, 8), 
                                 activation='relu', 
                                 padding='same', 
                                 input_shape=(rows, columns, channels))))
model1.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model1.add(TimeDistributed(Flatten()))

# add the LSTM layer, and a final Dense layer
model1.add(LSTM(units=5, activation='relu', stateful=False))
model1.add(Dense(4, activation='softmax'))
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model1.fit(Videos,y_trainOHE,epochs=40)
# Out:
# Train on 80 samples
# Epoch 1/40
# 80/80 [==============================] - 2s 30ms/sample - loss: 1.3637 - accuracy: 0.0125
# Epoch 2/40
# 80/80 [==============================] - 0s 978us/sample - loss: 1.3152 - accuracy: 0.2500
# Epoch 3/40
# 80/80 [==============================] - 0s 954us/sample - loss: 1.2358 - accuracy: 0.2500
# Epoch 4/40
# 80/80 [==============================] - 0s 949us/sample - loss: 1.1081 - accuracy: 0.4875
# Epoch 5/40
# 80/80 [==============================] - 0s 960us/sample - loss: 0.9503 - accuracy: 0.5250
# Epoch 6/40
# 80/80 [==============================] - 0s 956us/sample - loss: 0.6704 - accuracy: 0.7500
# Epoch 7/40
# 80/80 [==============================] - 0s 948us/sample - loss: 0.4169 - accuracy: 0.7500
# Epoch 8/40
# 80/80 [==============================] - 0s 954us/sample - loss: 0.3471 - accuracy: 0.8875
# Epoch 9/40
# 80/80 [==============================] - 0s 959us/sample - loss: 0.3421 - accuracy: 1.0000
# Epoch 10/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3536 - accuracy: 0.9875
# Epoch 11/40
# 80/80 [==============================] - 0s 935us/sample - loss: 0.3386 - accuracy: 1.0000
# Epoch 12/40
# 80/80 [==============================] - 0s 965us/sample - loss: 0.3368 - accuracy: 1.0000
# Epoch 13/40
# 80/80 [==============================] - 0s 922us/sample - loss: 0.3353 - accuracy: 1.0000
# Epoch 14/40
# 80/80 [==============================] - 0s 958us/sample - loss: 0.3336 - accuracy: 1.0000
# Epoch 15/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3320 - accuracy: 1.0000
# Epoch 16/40
# 80/80 [==============================] - 0s 954us/sample - loss: 0.3306 - accuracy: 1.0000
# Epoch 17/40
# 80/80 [==============================] - 0s 966us/sample - loss: 0.3294 - accuracy: 1.0000
# Epoch 18/40
# 80/80 [==============================] - 0s 948us/sample - loss: 0.3281 - accuracy: 1.0000
# Epoch 19/40
# 80/80 [==============================] - 0s 943us/sample - loss: 0.3265 - accuracy: 1.0000
# Epoch 20/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3251 - accuracy: 1.0000
# Epoch 21/40
# 80/80 [==============================] - 0s 994us/sample - loss: 0.3236 - accuracy: 1.0000
# Epoch 22/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3223 - accuracy: 1.0000
# Epoch 23/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3205 - accuracy: 1.0000
# Epoch 24/40
# 80/80 [==============================] - 0s 960us/sample - loss: 0.3190 - accuracy: 1.0000
# Epoch 25/40
# 80/80 [==============================] - 0s 951us/sample - loss: 0.3175 - accuracy: 1.0000
# Epoch 26/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3156 - accuracy: 1.0000
# Epoch 27/40
# 80/80 [==============================] - 0s 956us/sample - loss: 0.3143 - accuracy: 1.0000
# Epoch 28/40
# 80/80 [==============================] - 0s 951us/sample - loss: 0.3124 - accuracy: 1.0000
# Epoch 29/40
# 80/80 [==============================] - 0s 997us/sample - loss: 0.3108 - accuracy: 1.0000
# Epoch 30/40
# 80/80 [==============================] - 0s 958us/sample - loss: 0.3087 - accuracy: 1.0000
# Epoch 31/40
# 80/80 [==============================] - 0s 963us/sample - loss: 0.3071 - accuracy: 1.0000
# Epoch 32/40
# 80/80 [==============================] - 0s 982us/sample - loss: 0.3049 - accuracy: 1.0000
# Epoch 33/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3028 - accuracy: 1.0000
# Epoch 34/40
# 80/80 [==============================] - 0s 1ms/sample - loss: 0.3002 - accuracy: 1.0000
# Epoch 35/40
# 80/80 [==============================] - 0s 970us/sample - loss: 0.2975 - accuracy: 1.0000
# Epoch 36/40
# 80/80 [==============================] - 0s 858us/sample - loss: 0.2947 - accuracy: 1.0000
# Epoch 37/40
# 80/80 [==============================] - 0s 827us/sample - loss: 0.2908 - accuracy: 1.0000
# Epoch 38/40
# 80/80 [==============================] - 0s 855us/sample - loss: 0.2858 - accuracy: 1.0000
# Epoch 39/40
# 80/80 [==============================] - 0s 870us/sample - loss: 0.2801 - accuracy: 1.0000
# Epoch 40/40
# 80/80 [==============================] - 0s 856us/sample - loss: 0.2720 - accuracy: 1.0000

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri multiple                  85
# _________________________________________________________________
# time_distributed_1 (TimeDist multiple                  0
# _________________________________________________________________
# time_distributed_2 (TimeDist multiple                  1605
# _________________________________________________________________
# time_distributed_3 (TimeDist multiple                  0
# _________________________________________________________________
# time_distributed_4 (TimeDist multiple                  1605
# _________________________________________________________________
# time_distributed_5 (TimeDist multiple                  0
# _________________________________________________________________
# time_distributed_6 (TimeDist multiple                  0
# _________________________________________________________________
# lstm (LSTM)                  multiple                  9720
# _________________________________________________________________
# dense (Dense)                multiple                  24
# =================================================================
# Total params: 13,039
# Trainable params: 13,039
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Let's create a new set of videos to validate the model:

# %%
#Class sin
Videos1 = np.zeros((20,20,50,130,1))
for j in range(20):
    y = np.sin(t) + 0.05*np.random.randn(1, 20)
    y = y.flatten()
    for i in range(20):
        t2 = 6*(i+1)
        y2 = int(np.round(23*(y[i]+1)+4))
        Videos1[j,i,:,:,0] = f(t2,y2)/255
#Class constan
Videos2 = np.zeros((20,20,50,130,1))
for j in range(20):
    for i in range(20):
        t2 = int(np.round(25 + np.random.randn(1)))
        y2 = int(np.round(65 + np.random.randn(1)))
        Videos2[j,i,:,:,0] = f(t2,y2)/255
#Class ascending
Videos3 = np.zeros((20,20,50,130,1))
for j in range(20):
    for i in range(20):
        t2 = 6*(i+1)
        y2 = int(np.round(2*(i+1) + 2 + np.random.randn(1)))
        Videos3[j,i,:,:,0] = f(t2,y2)/255
#Class descending
Videos4 = np.zeros((20,20,50,130,1))
for j in range(20):
    for i in range(20):
        t2 = 6*(i+1)
        y2 = int(np.round(2*(20-i)+ 2 + np.random.randn(1)))
        Videos4[j,i,:,:,0] = f(t2,y2)/255
VideosTest = np.concatenate((Videos1,Videos2,Videos3,Videos4),axis=0)

# %%
y_est = np.argmax(model1.predict(VideosTest),axis=1)
print('accuracy testing = {}'.format(np.sum(y_est==Y)/80))
# Out:
# accuracy testing = 1.0

# %% [markdown]
# ## 3) Convolutional LSTM

# %%
from IPython.display import Image
Image(filename='local/imgs/ConvLSTM.png', width=600)

# %% [markdown]
# [Image taken from here](https://medium.com/neuronio/an-introduction-to-convlstm-55c9025563a7)
#
#
# ConvLSTMs are similar to a LSTMs, but the internal matrix multiplications are replaced by convolutions. The object that flows trough the cell is a 3D tensor instead of being just a 1D vector with features.

# %%
from tensorflow.keras.layers import ConvLSTM2D, BatchNormalization
frames = 20
model2 = Sequential()
model2.add(ConvLSTM2D(filters=5, kernel_size=(4, 4), 
                                 activation='relu', 
                                 padding='same', 
                                 input_shape=(frames,rows, columns, channels),return_sequences=True))
model2.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model2.add(ConvLSTM2D(filters=5, kernel_size=(8, 8), 
                                 activation='relu', 
                                padding='same', 
                                return_sequences=True))
model2.add(TimeDistributed(MaxPooling2D(pool_size=(2, 2))))
model2.add(ConvLSTM2D(filters=5, kernel_size=(8, 8), 
                                 activation='relu', 
                                 padding='same'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Flatten())

model2.add(Dense(4, activation='softmax'))
model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model2.fit(Videos,y_trainOHE,epochs=80)
# Out:
# Train on 80 samples
# Epoch 1/80
# 80/80 [==============================] - 1s 11ms/sample - loss: 0.8285 - accuracy: 1.0000
# Epoch 2/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.7929 - accuracy: 1.0000
# Epoch 3/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.7603 - accuracy: 1.0000
# Epoch 4/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.7291 - accuracy: 1.0000
# Epoch 5/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.6973 - accuracy: 1.0000
# Epoch 6/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.6661 - accuracy: 1.0000
# Epoch 7/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.6283 - accuracy: 1.0000
# Epoch 8/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.5889 - accuracy: 1.0000
# Epoch 9/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.5462 - accuracy: 1.0000
# Epoch 10/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.4985 - accuracy: 1.0000
# Epoch 11/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.4491 - accuracy: 1.0000
# Epoch 12/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.4001 - accuracy: 1.0000
# Epoch 13/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.3543 - accuracy: 1.0000
# Epoch 14/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.3173 - accuracy: 1.0000
# Epoch 15/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2847 - accuracy: 1.0000
# Epoch 16/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2613 - accuracy: 1.0000
# Epoch 17/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2441 - accuracy: 1.0000
# Epoch 18/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2312 - accuracy: 1.0000
# Epoch 19/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2210 - accuracy: 1.0000
# Epoch 20/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2116 - accuracy: 1.0000
# Epoch 21/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.2047 - accuracy: 1.0000
# Epoch 22/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1979 - accuracy: 1.0000
# Epoch 23/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1907 - accuracy: 1.0000
# Epoch 24/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1848 - accuracy: 1.0000
# Epoch 25/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1789 - accuracy: 1.0000
# Epoch 26/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1739 - accuracy: 1.0000
# Epoch 27/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1679 - accuracy: 1.0000
# Epoch 28/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1628 - accuracy: 1.0000
# Epoch 29/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1576 - accuracy: 1.0000
# Epoch 30/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1523 - accuracy: 1.0000
# Epoch 31/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1476 - accuracy: 1.0000
# Epoch 32/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1425 - accuracy: 1.0000
# Epoch 33/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1380 - accuracy: 1.0000
# Epoch 34/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1327 - accuracy: 1.0000
# Epoch 35/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1281 - accuracy: 1.0000
# Epoch 36/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1234 - accuracy: 1.0000
# Epoch 37/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1190 - accuracy: 1.0000
# Epoch 38/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1145 - accuracy: 1.0000
# Epoch 39/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1102 - accuracy: 1.0000
# Epoch 40/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1058 - accuracy: 1.0000
# Epoch 41/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.1014 - accuracy: 1.0000
# Epoch 42/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0976 - accuracy: 1.0000
# Epoch 43/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0937 - accuracy: 1.0000
# Epoch 44/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0891 - accuracy: 1.0000
# Epoch 45/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0855 - accuracy: 1.0000
# Epoch 46/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0817 - accuracy: 1.0000
# Epoch 47/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0779 - accuracy: 1.0000
# Epoch 48/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0741 - accuracy: 1.0000
# Epoch 49/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0704 - accuracy: 1.0000
# Epoch 50/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0673 - accuracy: 1.0000
# Epoch 51/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0638 - accuracy: 1.0000
# Epoch 52/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0605 - accuracy: 1.0000
# Epoch 53/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0569 - accuracy: 1.0000
# Epoch 54/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0538 - accuracy: 1.0000
# Epoch 55/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0512 - accuracy: 1.0000
# Epoch 56/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0480 - accuracy: 1.0000
# Epoch 57/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0452 - accuracy: 1.0000
# Epoch 58/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0427 - accuracy: 1.0000
# Epoch 59/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0402 - accuracy: 1.0000
# Epoch 60/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0376 - accuracy: 1.0000
# Epoch 61/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0354 - accuracy: 1.0000
# Epoch 62/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0333 - accuracy: 1.0000
# Epoch 63/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0311 - accuracy: 1.0000
# Epoch 64/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0291 - accuracy: 1.0000
# Epoch 65/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0273 - accuracy: 1.0000
# Epoch 66/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0256 - accuracy: 1.0000
# Epoch 67/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0239 - accuracy: 1.0000
# Epoch 68/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0223 - accuracy: 1.0000
# Epoch 69/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0208 - accuracy: 1.0000
# Epoch 70/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0195 - accuracy: 1.0000
# Epoch 71/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0184 - accuracy: 1.0000
# Epoch 72/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0170 - accuracy: 1.0000
# Epoch 73/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0159 - accuracy: 1.0000
# Epoch 74/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0149 - accuracy: 1.0000
# Epoch 75/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0139 - accuracy: 1.0000
# Epoch 76/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0130 - accuracy: 1.0000
# Epoch 77/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0122 - accuracy: 1.0000
# Epoch 78/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0114 - accuracy: 1.0000
# Epoch 79/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0108 - accuracy: 1.0000
# Epoch 80/80
# 80/80 [==============================] - 1s 9ms/sample - loss: 0.0100 - accuracy: 1.0000

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_lst_m2d (ConvLSTM2D)    (None, 20, 50, 130, 5)    1940
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 20, 25, 65, 5)     0
# _________________________________________________________________
# conv_lst_m2d_1 (ConvLSTM2D)  (None, 20, 25, 65, 5)     12820
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 20, 12, 32, 5)     0
# _________________________________________________________________
# conv_lst_m2d_2 (ConvLSTM2D)  (None, 12, 32, 5)         12820
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 16, 5)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 480)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 1924
# =================================================================
# Total params: 29,504
# Trainable params: 29,504
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_est = np.argmax(model2.predict(VideosTest),axis=1)
print('accuracy testing = {}'.format(np.sum(y_est==Y)/80))
# Out:
# accuracy testing = 1.0
