# %%
# !wget --no-cache -O init.py -q https://raw.githubusercontent.com/jdariasl/DiplomadoEPM_2019/master/Modulo3/init.py
from init import init; init(force_download=False)

# %%
import sys
if 'google.colab' in sys.modules:
    print ("setting tensorflow version in colab")
    # %tensorflow_version 2.x
import tensorflow as tf
tf.__version__
# Out:
# '2.1.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
mnist = pd.read_csv("local/data/mnist1.5k.csv.gz", compression="gzip", header=None).values
X=mnist[:,1:785]/255.
y=mnist[:,0]
print("dimension de las imagenes y las clases", X.shape, y.shape)
# Out:
# dimension de las imagenes y las clases (1500, 784) (1500,)

# %%
perm = np.random.permutation(list(range(X.shape[0])))[0:50]
random_imgs   = X[perm]
random_labels = y[perm] 
fig = plt.figure(figsize=(10,6))
for i in range(random_imgs.shape[0]):
    ax=fig.add_subplot(5,10,i+1)
    plt.imshow(random_imgs[i].reshape(28,28), interpolation="nearest", cmap = plt.cm.Greys_r)
    ax.set_title(int(random_labels[i]))
    ax.set_xticklabels([])
    ax.set_yticklabels([])

# %% [markdown]
# # 1. Autoencoders

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
from tensorflow.keras import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Input
from tensorflow.keras.backend import clear_session
import tensorflow as tf

# %%
def get_model(input_dim, code_size):

    inputs = Input(shape=input_dim)
    encoder = Dense(code_size, activation='relu')(inputs)
    avg_latent_activations = tf.reduce_mean(encoder, axis=0)
    outputs = Dense(input_dim, activation='sigmoid')(encoder)

    model = Model([inputs], [outputs])
    model.compile(optimizer='adam', loss='mse')
    return model, encoder, avg_latent_activations

# %% [markdown]
# porqué sigmoide en la última capa. qué pasaría si ponemos tanh o linear

# %%
model, encoder, avg_latent_activations = get_model(input_dim=X.shape[1], code_size=50)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                39250
# _________________________________________________________________
# dense_1 (Dense)              (None, 784)               39984
# =================================================================
# Total params: 79,234
# Trainable params: 79,234
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# try with larger layer, try with more layers

# %%
model.fit(X_train, X_train, epochs=100, batch_size=16)
# Out:
# Train on 1200 samples
# Epoch 1/100
# 1200/1200 [==============================] - 0s 246us/sample - loss: 0.1065
# Epoch 2/100
# 1200/1200 [==============================] - 0s 72us/sample - loss: 0.0614
# Epoch 3/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0501
# Epoch 4/100
# 1200/1200 [==============================] - 0s 61us/sample - loss: 0.0430
# Epoch 5/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0381
# Epoch 6/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0346
# Epoch 7/100
# 1200/1200 [==============================] - 0s 59us/sample - loss: 0.0317
# Epoch 8/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0293
# Epoch 9/100
# 1200/1200 [==============================] - 0s 61us/sample - loss: 0.0272
# Epoch 10/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0253
# Epoch 11/100
# 1200/1200 [==============================] - 0s 63us/sample - loss: 0.0238
# Epoch 82/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0047
# Epoch 83/100
# 1200/1200 [==============================] - 0s 67us/sample - loss: 0.0047
# Epoch 84/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0046
# Epoch 85/100
# 1200/1200 [==============================] - 0s 62us/sample - loss: 0.0046
# Epoch 86/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0046
# Epoch 87/100
# 1200/1200 [==============================] - 0s 60us/sample - loss: 0.0046
# Epoch 88/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0046
# Epoch 89/100
# 1200/1200 [==============================] - 0s 62us/sample - loss: 0.0045
# Epoch 90/100
# 1200/1200 [==============================] - 0s 62us/sample - loss: 0.0045
# Epoch 91/100
# 1200/1200 [==============================] - 0s 66us/sample - loss: 0.0045
# Epoch 92/100
# 1200/1200 [==============================] - 0s 66us/sample - loss: 0.0045
# Epoch 93/100
# 1200/1200 [==============================] - 0s 68us/sample - loss: 0.0044
# Epoch 94/100
# 1200/1200 [==============================] - 0s 62us/sample - loss: 0.0044
# Epoch 95/100
# 1200/1200 [==============================] - 0s 64us/sample - loss: 0.0044
# Epoch 96/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0044
# Epoch 97/100
# 1200/1200 [==============================] - 0s 65us/sample - loss: 0.0044
# Epoch 98/100
# 1200/1200 [==============================] - 0s 75us/sample - loss: 0.0043
# Epoch 99/100
# 1200/1200 [==============================] - 0s 79us/sample - loss: 0.0043
# Epoch 100/100
# 1200/1200 [==============================] - 0s 77us/sample - loss: 0.0043

# %% [markdown]
# observe the average activation of each latent neuron for all train data

# %%
from tensorflow.keras import backend as K
fl = K.function([model.input], [avg_latent_activations])
fl(X_train)
# Out:
# [array([7.524392 , 6.837592 , 4.8090487, 5.458294 , 2.020575 , 4.008631 ,
#         6.753833 , 4.5375094, 5.5560784, 4.9313974, 5.433612 , 6.0370584,
#         7.414014 , 3.87689  , 5.318111 , 6.1576552, 2.960775 , 5.858552 ,
#         6.1589108, 6.1510024, 4.6414614, 4.9903708, 5.9427032, 9.593964 ,
#         6.4304366, 5.209535 , 5.430751 , 6.362761 , 7.9224935, 7.0154257,
#         6.4275956, 3.8072445, 5.825841 , 7.701661 , 8.266263 , 5.640876 ,
#         5.2105227, 7.461784 , 5.0516014, 4.9443135, 7.470542 , 7.8527374,
#         4.793149 , 7.528982 , 8.549759 , 5.9274917, 7.319239 , 4.973787 ,
#         5.0019526, 4.2630043], dtype=float32)]

# %% [markdown]
# ### show reconstruction on sampled test images

# %%
X_sample = np.random.permutation(X_test)[:10]
X_pred   = model.predict(X_sample)

# %%
plt.figure(figsize=(20,5))
for i in range(len(X_sample)):
    plt.subplot(2,len(X_sample),i+1)
    plt.imshow(X_sample[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample),len(X_sample)+i+1)
    plt.imshow(X_pred[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# ### show weights

# %%
w = model.get_weights()
w[0].shape
# Out:
# (784, 50)

# %%
plt.figure(figsize=(6,6))
for k,i in enumerate(np.random.permutation(w[0].shape[1])[:100]):
    plt.subplot(10,10,k+1)
    plt.imshow(w[0][:,i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# ### see data in latent space

# %%
idxs = np.random.permutation(len(X_test))[:200]
idxs = idxs[np.argsort(y_test[idxs])]
y_sample = y_test[idxs]
X_sample = X_test[idxs]

import tensorflow.keras.backend as K
l0_output = K.function([model.input], [encoder])
X_sample_encoded = l0_output([X_sample])[0]
print("encoded data size", X_sample_encoded.shape)
plt.figure(figsize=(15,10))
plt.imshow(X_sample_encoded.T, cmap=plt.cm.Greys_r, origin="bottom")
plt.ylabel("component")
plt.xlabel("sample class number")
plt.xticks(range(len(y_sample))[::5], y_sample[::5]);
print ("mean activation at encoder %.3f"%np.mean(X_sample_encoded))
# Out:
# encoded data size (200, 50)
# mean activation at encoder 5.758

# %% [markdown]
# ### observe distribution of activations

# %%
plt.hist(X_sample_encoded.flatten(), bins=30);

# %% [markdown]
# ### avg representative of each class in latent space, reconstructed
#
# for each class:
# - take all train samples
# - obtain their representation in latent space
# - average all latent space representations
# - propage the averaged vector through the decoder

# %%
X_train_encoded = l0_output([X_train])[0]

fdecode = K.function([encoder], [model.outputs])
plt.figure(figsize=(15,3))
for k, i in enumerate(np.unique(y_train)):
    plt.subplot(1,10,k+1)
    plt.imshow(fdecode(X_train_encoded[y_train==i].mean(axis=0).reshape(1,-1))[0][0][0].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off"); plt.title("%d"%i);

# %% [markdown]
# ### most representative neuron in latent space for each class
#
# for each class:
# - take all train samples
# - obtain their representation in latent space
# - average all latent space representations
# - build a one hot vector in latent space with the activated neuron in average
# - propage the averaged vector through the decoder

# %%
X_train_encoded = l0_output([X_train])[0]
plt.figure(figsize=(15,3))
for k, i in enumerate(np.unique(y_train)):
    plt.subplot(1,10,k+1)
    k = np.zeros(50)
    most_activated_neuron = np.argmax(X_train_encoded[y_train==i].mean(axis=0))
    k[np.argmax(X_train_encoded[y_train==i].mean(axis=0))] = 1
    print ("class %d, most avg activated neuron is %d, with value %.2f"%(i, most_activated_neuron, np.max(X_train_encoded[y_train==i].mean(axis=0))))
    plt.imshow(fdecode(k.reshape(1,-1))[0][0][0].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off"); plt.title("%d"%i);
# Out:
# class 0, most avg activated neuron is 23, with value 15.42
# class 1, most avg activated neuron is 17, with value 8.49
# class 2, most avg activated neuron is 41, with value 12.33
# class 3, most avg activated neuron is 44, with value 14.59
# class 4, most avg activated neuron is 34, with value 12.19
# class 5, most avg activated neuron is 23, with value 11.80
# class 6, most avg activated neuron is 41, with value 13.18
# class 7, most avg activated neuron is 43, with value 12.86
# class 8, most avg activated neuron is 23, with value 12.39
# class 9, most avg activated neuron is 43, with value 12.26

# %% [markdown]
# # 2. Custom loss, unsupervised `.fit(X)` call
#
# given:
#
# - $\mathbf{x}^{(i)} \in \mathbb{R}^{784}$
# - $e(\mathbf{x}^{(i)}) \in \mathbb{R}^{50}$, the encoder
# - $d(e(\mathbf{x}^{(i)})) \in \mathbb{R}^{784}$, the decoder
#
# we define the loss function as (MSE):
#
# $$\text{loss}(\mathbf{x}^{(i)}) = \frac{1}{m}\sum_m \big(\mathbf{x}^{(i)} - d(e(\mathbf{x}^{(i)}))\big)^2$$
#
# and implement it by hand

# %%
from tensorflow.keras import backend as K
from tensorflow.keras.losses import mse
import tensorflow as tf

def get_model_U(input_dim, code_size):
    inputs = Input(shape=input_dim)
    encoder = Dense(code_size, activation='relu')(inputs)
    outputs = Dense(input_dim, activation='sigmoid')(encoder)

    loss = tf.reduce_mean( (inputs-outputs)**2)
    model = Model([inputs], [outputs])    
    model.add_loss(loss)
    
    model.compile(optimizer='adam')
    return model, encoder

# %%
model, encoder = get_model_U(input_dim=X.shape[1], code_size=40)
model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0226 11:53:05.187875 4625851840 training_utils.py:1444] Output dense_3 missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to dense_3.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 784)]        0
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 40)           31400       input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 784)          32144       dense_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_sub (TensorFlowOpLa [(None, 784)]        0           input_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_pow (TensorFlowOpLa [(None, 784)]        0           tf_op_layer_sub[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_Mean_1 (TensorFlowO [()]                 0           tf_op_layer_pow[0][0]
# __________________________________________________________________________________________________
# add_loss (AddLoss)              ()                   0           tf_op_layer_Mean_1[0][0]
# ==================================================================================================
# Total params: 63,544
# Trainable params: 63,544
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# observe `.fit` call is unsupervised

# %%
model.fit(X_train, epochs=100, batch_size=32)
# Out:
# Train on 1200 samples
# Epoch 1/100
# 1200/1200 [==============================] - 0s 175us/sample - loss: 0.1462
# Epoch 2/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0706
# Epoch 3/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0628
# Epoch 4/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0559
# Epoch 5/100
# 1200/1200 [==============================] - 0s 39us/sample - loss: 0.0509
# Epoch 6/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0470
# Epoch 7/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0438
# Epoch 8/100
# 1200/1200 [==============================] - 0s 44us/sample - loss: 0.0410
# Epoch 9/100
# 1200/1200 [==============================] - 0s 43us/sample - loss: 0.0387
# Epoch 10/100
# 1200/1200 [==============================] - 0s 42us/sample - loss: 0.0368
# Epoch 11/100
# 1200/1200 [==============================] - 0s 40us/sample - loss: 0.0351
# Epoch 12/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0334
# Epoch 13/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0320
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0079
# Epoch 85/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0078
# Epoch 86/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0078
# Epoch 87/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0077
# Epoch 88/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0076
# Epoch 89/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0076
# Epoch 90/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0075
# Epoch 91/100
# 1200/1200 [==============================] - 0s 51us/sample - loss: 0.0075
# Epoch 92/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0074
# Epoch 93/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0074
# Epoch 94/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0074
# Epoch 95/100
# 1200/1200 [==============================] - 0s 52us/sample - loss: 0.0073
# Epoch 96/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0073
# Epoch 97/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0072
# Epoch 98/100
# 1200/1200 [==============================] - 0s 49us/sample - loss: 0.0072
# Epoch 99/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0072
# Epoch 100/100
# 1200/1200 [==============================] - 0s 50us/sample - loss: 0.0072

# %%
X_sample = np.random.permutation(X_test)[:10]
X_pred   = model.predict(X_sample)

plt.figure(figsize=(20,5))
for i in range(len(X_sample)):
    plt.subplot(2,len(X_sample),i+1)
    plt.imshow(X_sample[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample),len(X_sample)+i+1)
    plt.imshow(X_pred[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# # 3. Autoencoder for image denoising
#
# observe reconstruction when fed with noisy data

# %%
def add_noise(x, noise_level=.2):
    return x + np.random.normal(size=x.shape)*noise_level

# %%
X_sample = np.random.permutation(X_test)[:10]
X_pred   = model.predict(X_sample)
X_sample_noisy = add_noise(X_sample)
X_pred_noisy   = model.predict(X_sample_noisy)

# %%
plt.figure(figsize=(20,5))
for i in range(len(X_sample_noisy)):
    plt.subplot(2,len(X_sample_noisy),i+1)
    plt.imshow(X_sample_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample_noisy),len(X_sample_noisy)+i+1)
    plt.imshow(X_pred_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")

# %% [markdown]
# ### in a more real scenario we only have noisy data to train the model

# %%
n_model, n_encoder,_ = get_model(input_dim=X.shape[1], code_size=40)
X_train_noisy = add_noise(X_train)

n_model.fit(X_train_noisy, X_train_noisy, epochs=100, batch_size=32)
# Out:
# Train on 1200 samples
# Epoch 1/100
# 1200/1200 [==============================] - 0s 188us/sample - loss: 0.1851
# Epoch 72/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0465
# Epoch 73/100
# 1200/1200 [==============================] - 0s 47us/sample - loss: 0.0464
# Epoch 74/100
# 1200/1200 [==============================] - 0s 40us/sample - loss: 0.0463
# Epoch 75/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0463
# Epoch 76/100
# 1200/1200 [==============================] - 0s 42us/sample - loss: 0.0462
# Epoch 77/100
# 1200/1200 [==============================] - 0s 38us/sample - loss: 0.0461
# Epoch 78/100
# 1200/1200 [==============================] - 0s 39us/sample - loss: 0.0460
# Epoch 79/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0459
# Epoch 80/100
# 1200/1200 [==============================] - 0s 38us/sample - loss: 0.0458
# Epoch 81/100
# 1200/1200 [==============================] - 0s 38us/sample - loss: 0.0458
# Epoch 82/100
# 1200/1200 [==============================] - 0s 40us/sample - loss: 0.0457
# Epoch 83/100
# 1200/1200 [==============================] - 0s 42us/sample - loss: 0.0456
# Epoch 84/100
# 1200/1200 [==============================] - 0s 38us/sample - loss: 0.0456
# Epoch 85/100
# 1200/1200 [==============================] - 0s 41us/sample - loss: 0.0455
# Epoch 86/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0454
# Epoch 87/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0454
# Epoch 88/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0453
# Epoch 89/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0453
# Epoch 90/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0452
# Epoch 91/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0452
# Epoch 92/100
# 1200/1200 [==============================] - 0s 44us/sample - loss: 0.0451
# Epoch 93/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0450
# Epoch 94/100
# 1200/1200 [==============================] - 0s 48us/sample - loss: 0.0450
# Epoch 95/100
# 1200/1200 [==============================] - 0s 46us/sample - loss: 0.0449
# Epoch 96/100
# 1200/1200 [==============================] - 0s 43us/sample - loss: 0.0449
# Epoch 97/100
# 1200/1200 [==============================] - 0s 44us/sample - loss: 0.0449
# Epoch 98/100
# 1200/1200 [==============================] - 0s 44us/sample - loss: 0.0448
# Epoch 99/100
# 1200/1200 [==============================] - 0s 45us/sample - loss: 0.0447
# Epoch 100/100
# 1200/1200 [==============================] - 0s 42us/sample - loss: 0.0447

# %%
X_sample_noisy = add_noise(X_sample)
X_pred_noisy   = n_model.predict(X_sample_noisy)

plt.figure(figsize=(20,5))
for i in range(len(X_sample_noisy)):
    plt.subplot(2,len(X_sample_noisy),i+1)
    plt.imshow(X_sample_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
    plt.subplot(2,len(X_sample_noisy),len(X_sample_noisy)+i+1)
    plt.imshow(X_pred_noisy[i].reshape(28,28), cmap=plt.cm.Greys_r)
    plt.axis("off")
